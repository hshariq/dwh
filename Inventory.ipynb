# %%
import pandas as pd
from faker import Faker

fake = Faker(use_weighting=True,locale='en_US')
# Out:
# C:\Users\hamza\AppData\Local\Temp\ipykernel_6132\3291989358.py:1: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd

# %%
import pandas as pd

# Define column names for Inventory table
Inventory_columns = ['InventoryID', 'InventoryName', 
                     'InventoryRackNumber', 'InventoryBatchNumber', 
                     'Inventory_Initial_Quantity_Ordered', 
                     'InventoryQuantityUsed',
                     'InventoryQuantityinTransit', 
                     'InventoryQuantityinStock',
                     'InventoryReorderThreshold', 
                     'InventoryDamagedQuantity', 
                     'InventoryStockStatus', 'InventoryType', 
                     'WarehouseID', 'RawMaterialID']

# Create an empty DataFrame with the specified column names
df = pd.DataFrame(columns=Inventory_columns)

# Display the empty DataFrame
df
# Out:
# Empty DataFrame
# Columns: [InventoryID, InventoryName, InventoryRackNumber, InventoryBatchNumber, Inventory_Initial_Quantity_Ordered, InventoryQuantityUsed, InventoryQuantityinTransit, InventoryQuantityinStock, InventoryReorderThreshold, InventoryDamagedQuantity, InventoryStockStatus, InventoryType, WarehouseID, RawMaterialID]
# Index: []

# %%
import random
q= []
for i in range(1,501):
    q.append(i)
        
df['InventoryID'] = q
df
# Out:
#      InventoryID InventoryName InventoryRackNumber InventoryBatchNumber  \
# 0              1           NaN                 NaN                  NaN
# 1              2           NaN                 NaN                  NaN
# 2              3           NaN                 NaN                  NaN
# 3              4           NaN                 NaN                  NaN
# 4              5           NaN                 NaN                  NaN
# ..           ...           ...                 ...                  ...
# 495          496           NaN                 NaN                  NaN
# 496          497           NaN                 NaN                  NaN
# 497          498           NaN                 NaN                  NaN
# 498          499           NaN                 NaN                  NaN
# 499          500           NaN                 NaN                  NaN
#
#     Inventory_Initial_Quantity_Ordered InventoryQuantityUsed  \
# 0                                  NaN                   NaN
# 1                                  NaN                   NaN
# 2                                  NaN                   NaN
# 3                                  NaN                   NaN
# 4                                  NaN                   NaN
# ..                                 ...                   ...
# 495                                NaN                   NaN
# 496                                NaN                   NaN
# 497                                NaN                   NaN
# 498                                NaN                   NaN
# 499                                NaN                   NaN
#
#     InventoryQuantityinTransit InventoryQuantityinStock  \
# 0                          NaN                      NaN
# 1                          NaN                      NaN
# 2                          NaN                      NaN
# 3                          NaN                      NaN
# 4                          NaN                      NaN
# ..                         ...                      ...
# 495                        NaN                      NaN
# 496                        NaN                      NaN
# 497                        NaN                      NaN
# 498                        NaN                      NaN
# 499                        NaN                      NaN
#
#     InventoryReorderThreshold InventoryDamagedQuantity InventoryStockStatus  \
# 0                         NaN                      NaN                  NaN
# 1                         NaN                      NaN                  NaN
# 2                         NaN                      NaN                  NaN
# 3                         NaN                      NaN                  NaN
# 4                         NaN                      NaN                  NaN
# ..                        ...                      ...                  ...
# 495                       NaN                      NaN                  NaN
# 496                       NaN                      NaN                  NaN
# 497                       NaN                      NaN                  NaN
# 498                       NaN                      NaN                  NaN
# 499                       NaN                      NaN                  NaN
#
#     InventoryType WarehouseID RawMaterialID
# 0             NaN         NaN           NaN
# 1             NaN         NaN           NaN
# 2             NaN         NaN           NaN
# 3             NaN         NaN           NaN
# 4             NaN         NaN           NaN
# ..            ...         ...           ...
# 495           NaN         NaN           NaN
# 496           NaN         NaN           NaN
# 497           NaN         NaN           NaN
# 498           NaN         NaN           NaN
# 499           NaN         NaN           NaN
#
# [500 rows x 14 columns]

# %%
df['InventoryName'] = df['InventoryID'].map(lambda x: "Inv" + str(x))
df
# Out:
#      InventoryID InventoryName InventoryRackNumber InventoryBatchNumber  \
# 0              1          Inv1                 NaN                  NaN
# 1              2          Inv2                 NaN                  NaN
# 2              3          Inv3                 NaN                  NaN
# 3              4          Inv4                 NaN                  NaN
# 4              5          Inv5                 NaN                  NaN
# ..           ...           ...                 ...                  ...
# 495          496        Inv496                 NaN                  NaN
# 496          497        Inv497                 NaN                  NaN
# 497          498        Inv498                 NaN                  NaN
# 498          499        Inv499                 NaN                  NaN
# 499          500        Inv500                 NaN                  NaN
#
#     Inventory_Initial_Quantity_Ordered InventoryQuantityUsed  \
# 0                                  NaN                   NaN
# 1                                  NaN                   NaN
# 2                                  NaN                   NaN
# 3                                  NaN                   NaN
# 4                                  NaN                   NaN
# ..                                 ...                   ...
# 495                                NaN                   NaN
# 496                                NaN                   NaN
# 497                                NaN                   NaN
# 498                                NaN                   NaN
# 499                                NaN                   NaN
#
#     InventoryQuantityinTransit InventoryQuantityinStock  \
# 0                          NaN                      NaN
# 1                          NaN                      NaN
# 2                          NaN                      NaN
# 3                          NaN                      NaN
# 4                          NaN                      NaN
# ..                         ...                      ...
# 495                        NaN                      NaN
# 496                        NaN                      NaN
# 497                        NaN                      NaN
# 498                        NaN                      NaN
# 499                        NaN                      NaN
#
#     InventoryReorderThreshold InventoryDamagedQuantity InventoryStockStatus  \
# 0                         NaN                      NaN                  NaN
# 1                         NaN                      NaN                  NaN
# 2                         NaN                      NaN                  NaN
# 3                         NaN                      NaN                  NaN
# 4                         NaN                      NaN                  NaN
# ..                        ...                      ...                  ...
# 495                       NaN                      NaN                  NaN
# 496                       NaN                      NaN                  NaN
# 497                       NaN                      NaN                  NaN
# 498                       NaN                      NaN                  NaN
# 499                       NaN                      NaN                  NaN
#
#     InventoryType WarehouseID RawMaterialID
# 0             NaN         NaN           NaN
# 1             NaN         NaN           NaN
# 2             NaN         NaN           NaN
# 3             NaN         NaN           NaN
# 4             NaN         NaN           NaN
# ..            ...         ...           ...
# 495           NaN         NaN           NaN
# 496           NaN         NaN           NaN
# 497           NaN         NaN           NaN
# 498           NaN         NaN           NaN
# 499           NaN         NaN           NaN
#
# [500 rows x 14 columns]

# %%
#randomly add InventoryRackNumber
df['InventoryRackNumber'] = random.sample(range(1, 1000), 500)
df
# Out:
#      InventoryID InventoryName  InventoryRackNumber InventoryBatchNumber  \
# 0              1          Inv1                  146                  NaN
# 1              2          Inv2                  665                  NaN
# 2              3          Inv3                  481                  NaN
# 3              4          Inv4                  253                  NaN
# 4              5          Inv5                  735                  NaN
# ..           ...           ...                  ...                  ...
# 495          496        Inv496                  850                  NaN
# 496          497        Inv497                  593                  NaN
# 497          498        Inv498                  409                  NaN
# 498          499        Inv499                   35                  NaN
# 499          500        Inv500                  692                  NaN
#
#     Inventory_Initial_Quantity_Ordered InventoryQuantityUsed  \
# 0                                  NaN                   NaN
# 1                                  NaN                   NaN
# 2                                  NaN                   NaN
# 3                                  NaN                   NaN
# 4                                  NaN                   NaN
# ..                                 ...                   ...
# 495                                NaN                   NaN
# 496                                NaN                   NaN
# 497                                NaN                   NaN
# 498                                NaN                   NaN
# 499                                NaN                   NaN
#
#     InventoryQuantityinTransit InventoryQuantityinStock  \
# 0                          NaN                      NaN
# 1                          NaN                      NaN
# 2                          NaN                      NaN
# 3                          NaN                      NaN
# 4                          NaN                      NaN
# ..                         ...                      ...
# 495                        NaN                      NaN
# 496                        NaN                      NaN
# 497                        NaN                      NaN
# 498                        NaN                      NaN
# 499                        NaN                      NaN
#
#     InventoryReorderThreshold InventoryDamagedQuantity InventoryStockStatus  \
# 0                         NaN                      NaN                  NaN
# 1                         NaN                      NaN                  NaN
# 2                         NaN                      NaN                  NaN
# 3                         NaN                      NaN                  NaN
# 4                         NaN                      NaN                  NaN
# ..                        ...                      ...                  ...
# 495                       NaN                      NaN                  NaN
# 496                       NaN                      NaN                  NaN
# 497                       NaN                      NaN                  NaN
# 498                       NaN                      NaN                  NaN
# 499                       NaN                      NaN                  NaN
#
#     InventoryType WarehouseID RawMaterialID
# 0             NaN         NaN           NaN
# 1             NaN         NaN           NaN
# 2             NaN         NaN           NaN
# 3             NaN         NaN           NaN
# 4             NaN         NaN           NaN
# ..            ...         ...           ...
# 495           NaN         NaN           NaN
# 496           NaN         NaN           NaN
# 497           NaN         NaN           NaN
# 498           NaN         NaN           NaN
# 499           NaN         NaN           NaN
#
# [500 rows x 14 columns]

# %%
#randomly add InventoryRackNumber
df['InventoryBatchNumber'] = random.sample(range(1, 1500), 500)
df
# Out:
#      InventoryID InventoryName  InventoryRackNumber  InventoryBatchNumber  \
# 0              1          Inv1                  146                   913
# 1              2          Inv2                  665                    37
# 2              3          Inv3                  481                   799
# 3              4          Inv4                  253                   922
# 4              5          Inv5                  735                   532
# ..           ...           ...                  ...                   ...
# 495          496        Inv496                  850                    84
# 496          497        Inv497                  593                  1473
# 497          498        Inv498                  409                   804
# 498          499        Inv499                   35                   482
# 499          500        Inv500                  692                   979
#
#     Inventory_Initial_Quantity_Ordered InventoryQuantityUsed  \
# 0                                  NaN                   NaN
# 1                                  NaN                   NaN
# 2                                  NaN                   NaN
# 3                                  NaN                   NaN
# 4                                  NaN                   NaN
# ..                                 ...                   ...
# 495                                NaN                   NaN
# 496                                NaN                   NaN
# 497                                NaN                   NaN
# 498                                NaN                   NaN
# 499                                NaN                   NaN
#
#     InventoryQuantityinTransit InventoryQuantityinStock  \
# 0                          NaN                      NaN
# 1                          NaN                      NaN
# 2                          NaN                      NaN
# 3                          NaN                      NaN
# 4                          NaN                      NaN
# ..                         ...                      ...
# 495                        NaN                      NaN
# 496                        NaN                      NaN
# 497                        NaN                      NaN
# 498                        NaN                      NaN
# 499                        NaN                      NaN
#
#     InventoryReorderThreshold InventoryDamagedQuantity InventoryStockStatus  \
# 0                         NaN                      NaN                  NaN
# 1                         NaN                      NaN                  NaN
# 2                         NaN                      NaN                  NaN
# 3                         NaN                      NaN                  NaN
# 4                         NaN                      NaN                  NaN
# ..                        ...                      ...                  ...
# 495                       NaN                      NaN                  NaN
# 496                       NaN                      NaN                  NaN
# 497                       NaN                      NaN                  NaN
# 498                       NaN                      NaN                  NaN
# 499                       NaN                      NaN                  NaN
#
#     InventoryType WarehouseID RawMaterialID
# 0             NaN         NaN           NaN
# 1             NaN         NaN           NaN
# 2             NaN         NaN           NaN
# 3             NaN         NaN           NaN
# 4             NaN         NaN           NaN
# ..            ...         ...           ...
# 495           NaN         NaN           NaN
# 496           NaN         NaN           NaN
# 497           NaN         NaN           NaN
# 498           NaN         NaN           NaN
# 499           NaN         NaN           NaN
#
# [500 rows x 14 columns]

# %%
# randomly add InventoryRackNumber
df['Inventory_Initial_Quantity_Ordered'] = random.choices(range(100, 300), k=len(df))
df
# Out:
#      InventoryID InventoryName  InventoryRackNumber  InventoryBatchNumber  \
# 0              1          Inv1                  146                   913
# 1              2          Inv2                  665                    37
# 2              3          Inv3                  481                   799
# 3              4          Inv4                  253                   922
# 4              5          Inv5                  735                   532
# ..           ...           ...                  ...                   ...
# 495          496        Inv496                  850                    84
# 496          497        Inv497                  593                  1473
# 497          498        Inv498                  409                   804
# 498          499        Inv499                   35                   482
# 499          500        Inv500                  692                   979
#
#      Inventory_Initial_Quantity_Ordered InventoryQuantityUsed  \
# 0                                   230                   NaN
# 1                                   293                   NaN
# 2                                   290                   NaN
# 3                                   223                   NaN
# 4                                   186                   NaN
# ..                                  ...                   ...
# 495                                 106                   NaN
# 496                                 202                   NaN
# 497                                 101                   NaN
# 498                                 166                   NaN
# 499                                 224                   NaN
#
#     InventoryQuantityinTransit InventoryQuantityinStock  \
# 0                          NaN                      NaN
# 1                          NaN                      NaN
# 2                          NaN                      NaN
# 3                          NaN                      NaN
# 4                          NaN                      NaN
# ..                         ...                      ...
# 495                        NaN                      NaN
# 496                        NaN                      NaN
# 497                        NaN                      NaN
# 498                        NaN                      NaN
# 499                        NaN                      NaN
#
#     InventoryReorderThreshold InventoryDamagedQuantity InventoryStockStatus  \
# 0                         NaN                      NaN                  NaN
# 1                         NaN                      NaN                  NaN
# 2                         NaN                      NaN                  NaN
# 3                         NaN                      NaN                  NaN
# 4                         NaN                      NaN                  NaN
# ..                        ...                      ...                  ...
# 495                       NaN                      NaN                  NaN
# 496                       NaN                      NaN                  NaN
# 497                       NaN                      NaN                  NaN
# 498                       NaN                      NaN                  NaN
# 499                       NaN                      NaN                  NaN
#
#     InventoryType WarehouseID RawMaterialID
# 0             NaN         NaN           NaN
# 1             NaN         NaN           NaN
# 2             NaN         NaN           NaN
# 3             NaN         NaN           NaN
# 4             NaN         NaN           NaN
# ..            ...         ...           ...
# 495           NaN         NaN           NaN
# 496           NaN         NaN           NaN
# 497           NaN         NaN           NaN
# 498           NaN         NaN           NaN
# 499           NaN         NaN           NaN
#
# [500 rows x 14 columns]

# %%
df['InventoryQuantityUsed'] = random.choices(range(1, 100), k=len(df))
df
# Out:
#      InventoryID InventoryName  InventoryRackNumber  InventoryBatchNumber  \
# 0              1          Inv1                  146                   913
# 1              2          Inv2                  665                    37
# 2              3          Inv3                  481                   799
# 3              4          Inv4                  253                   922
# 4              5          Inv5                  735                   532
# ..           ...           ...                  ...                   ...
# 495          496        Inv496                  850                    84
# 496          497        Inv497                  593                  1473
# 497          498        Inv498                  409                   804
# 498          499        Inv499                   35                   482
# 499          500        Inv500                  692                   979
#
#      Inventory_Initial_Quantity_Ordered  InventoryQuantityUsed  \
# 0                                   230                     39
# 1                                   293                     28
# 2                                   290                     63
# 3                                   223                     56
# 4                                   186                     45
# ..                                  ...                    ...
# 495                                 106                     74
# 496                                 202                     51
# 497                                 101                     11
# 498                                 166                     16
# 499                                 224                      9
#
#     InventoryQuantityinTransit InventoryQuantityinStock  \
# 0                          NaN                      NaN
# 1                          NaN                      NaN
# 2                          NaN                      NaN
# 3                          NaN                      NaN
# 4                          NaN                      NaN
# ..                         ...                      ...
# 495                        NaN                      NaN
# 496                        NaN                      NaN
# 497                        NaN                      NaN
# 498                        NaN                      NaN
# 499                        NaN                      NaN
#
#     InventoryReorderThreshold InventoryDamagedQuantity InventoryStockStatus  \
# 0                         NaN                      NaN                  NaN
# 1                         NaN                      NaN                  NaN
# 2                         NaN                      NaN                  NaN
# 3                         NaN                      NaN                  NaN
# 4                         NaN                      NaN                  NaN
# ..                        ...                      ...                  ...
# 495                       NaN                      NaN                  NaN
# 496                       NaN                      NaN                  NaN
# 497                       NaN                      NaN                  NaN
# 498                       NaN                      NaN                  NaN
# 499                       NaN                      NaN                  NaN
#
#     InventoryType WarehouseID RawMaterialID
# 0             NaN         NaN           NaN
# 1             NaN         NaN           NaN
# 2             NaN         NaN           NaN
# 3             NaN         NaN           NaN
# 4             NaN         NaN           NaN
# ..            ...         ...           ...
# 495           NaN         NaN           NaN
# 496           NaN         NaN           NaN
# 497           NaN         NaN           NaN
# 498           NaN         NaN           NaN
# 499           NaN         NaN           NaN
#
# [500 rows x 14 columns]

# %%
# randomly add InventoryRackNumber
df['InventoryQuantityinTransit'] = random.choices(range(20, 60), k=len(df))
df
# Out:
#      InventoryID InventoryName  InventoryRackNumber  InventoryBatchNumber  \
# 0              1          Inv1                  146                   913
# 1              2          Inv2                  665                    37
# 2              3          Inv3                  481                   799
# 3              4          Inv4                  253                   922
# 4              5          Inv5                  735                   532
# ..           ...           ...                  ...                   ...
# 495          496        Inv496                  850                    84
# 496          497        Inv497                  593                  1473
# 497          498        Inv498                  409                   804
# 498          499        Inv499                   35                   482
# 499          500        Inv500                  692                   979
#
#      Inventory_Initial_Quantity_Ordered  InventoryQuantityUsed  \
# 0                                   230                     39
# 1                                   293                     28
# 2                                   290                     63
# 3                                   223                     56
# 4                                   186                     45
# ..                                  ...                    ...
# 495                                 106                     74
# 496                                 202                     51
# 497                                 101                     11
# 498                                 166                     16
# 499                                 224                      9
#
#      InventoryQuantityinTransit InventoryQuantityinStock  \
# 0                            21                      NaN
# 1                            50                      NaN
# 2                            58                      NaN
# 3                            44                      NaN
# 4                            57                      NaN
# ..                          ...                      ...
# 495                          34                      NaN
# 496                          56                      NaN
# 497                          53                      NaN
# 498                          29                      NaN
# 499                          21                      NaN
#
#     InventoryReorderThreshold InventoryDamagedQuantity InventoryStockStatus  \
# 0                         NaN                      NaN                  NaN
# 1                         NaN                      NaN                  NaN
# 2                         NaN                      NaN                  NaN
# 3                         NaN                      NaN                  NaN
# 4                         NaN                      NaN                  NaN
# ..                        ...                      ...                  ...
# 495                       NaN                      NaN                  NaN
# 496                       NaN                      NaN                  NaN
# 497                       NaN                      NaN                  NaN
# 498                       NaN                      NaN                  NaN
# 499                       NaN                      NaN                  NaN
#
#     InventoryType WarehouseID RawMaterialID
# 0             NaN         NaN           NaN
# 1             NaN         NaN           NaN
# 2             NaN         NaN           NaN
# 3             NaN         NaN           NaN
# 4             NaN         NaN           NaN
# ..            ...         ...           ...
# 495           NaN         NaN           NaN
# 496           NaN         NaN           NaN
# 497           NaN         NaN           NaN
# 498           NaN         NaN           NaN
# 499           NaN         NaN           NaN
#
# [500 rows x 14 columns]

# %%
# randomly add InventoryRackNumber
df['InventoryDamagedQuantity'] = random.choices(range(5, 10), k=len(df))
df
# Out:
#      InventoryID InventoryName  InventoryRackNumber  InventoryBatchNumber  \
# 0              1          Inv1                  146                   913
# 1              2          Inv2                  665                    37
# 2              3          Inv3                  481                   799
# 3              4          Inv4                  253                   922
# 4              5          Inv5                  735                   532
# ..           ...           ...                  ...                   ...
# 495          496        Inv496                  850                    84
# 496          497        Inv497                  593                  1473
# 497          498        Inv498                  409                   804
# 498          499        Inv499                   35                   482
# 499          500        Inv500                  692                   979
#
#      Inventory_Initial_Quantity_Ordered  InventoryQuantityUsed  \
# 0                                   230                     39
# 1                                   293                     28
# 2                                   290                     63
# 3                                   223                     56
# 4                                   186                     45
# ..                                  ...                    ...
# 495                                 106                     74
# 496                                 202                     51
# 497                                 101                     11
# 498                                 166                     16
# 499                                 224                      9
#
#      InventoryQuantityinTransit InventoryQuantityinStock  \
# 0                            21                      NaN
# 1                            50                      NaN
# 2                            58                      NaN
# 3                            44                      NaN
# 4                            57                      NaN
# ..                          ...                      ...
# 495                          34                      NaN
# 496                          56                      NaN
# 497                          53                      NaN
# 498                          29                      NaN
# 499                          21                      NaN
#
#     InventoryReorderThreshold  InventoryDamagedQuantity InventoryStockStatus  \
# 0                         NaN                         6                  NaN
# 1                         NaN                         6                  NaN
# 2                         NaN                         9                  NaN
# 3                         NaN                         7                  NaN
# 4                         NaN                         8                  NaN
# ..                        ...                       ...                  ...
# 495                       NaN                         9                  NaN
# 496                       NaN                         9                  NaN
# 497                       NaN                         7                  NaN
# 498                       NaN                         5                  NaN
# 499                       NaN                         8                  NaN
#
#     InventoryType WarehouseID RawMaterialID
# 0             NaN         NaN           NaN
# 1             NaN         NaN           NaN
# 2             NaN         NaN           NaN
# 3             NaN         NaN           NaN
# 4             NaN         NaN           NaN
# ..            ...         ...           ...
# 495           NaN         NaN           NaN
# 496           NaN         NaN           NaN
# 497           NaN         NaN           NaN
# 498           NaN         NaN           NaN
# 499           NaN         NaN           NaN
#
# [500 rows x 14 columns]

# %%
#qunaity orderd - qunaity used is InventoryQuantityinStock
df['InventoryQuantityinStock'] = df['Inventory_Initial_Quantity_Ordered'] - df['InventoryQuantityUsed']
df
# Out:
#      InventoryID InventoryName  InventoryRackNumber  InventoryBatchNumber  \
# 0              1          Inv1                  146                   913
# 1              2          Inv2                  665                    37
# 2              3          Inv3                  481                   799
# 3              4          Inv4                  253                   922
# 4              5          Inv5                  735                   532
# ..           ...           ...                  ...                   ...
# 495          496        Inv496                  850                    84
# 496          497        Inv497                  593                  1473
# 497          498        Inv498                  409                   804
# 498          499        Inv499                   35                   482
# 499          500        Inv500                  692                   979
#
#      Inventory_Initial_Quantity_Ordered  InventoryQuantityUsed  \
# 0                                   230                     39
# 1                                   293                     28
# 2                                   290                     63
# 3                                   223                     56
# 4                                   186                     45
# ..                                  ...                    ...
# 495                                 106                     74
# 496                                 202                     51
# 497                                 101                     11
# 498                                 166                     16
# 499                                 224                      9
#
#      InventoryQuantityinTransit  InventoryQuantityinStock  \
# 0                            21                       191
# 1                            50                       265
# 2                            58                       227
# 3                            44                       167
# 4                            57                       141
# ..                          ...                       ...
# 495                          34                        32
# 496                          56                       151
# 497                          53                        90
# 498                          29                       150
# 499                          21                       215
#
#     InventoryReorderThreshold  InventoryDamagedQuantity InventoryStockStatus  \
# 0                         NaN                         6                  NaN
# 1                         NaN                         6                  NaN
# 2                         NaN                         9                  NaN
# 3                         NaN                         7                  NaN
# 4                         NaN                         8                  NaN
# ..                        ...                       ...                  ...
# 495                       NaN                         9                  NaN
# 496                       NaN                         9                  NaN
# 497                       NaN                         7                  NaN
# 498                       NaN                         5                  NaN
# 499                       NaN                         8                  NaN
#
#     InventoryType WarehouseID RawMaterialID
# 0             NaN         NaN           NaN
# 1             NaN         NaN           NaN
# 2             NaN         NaN           NaN
# 3             NaN         NaN           NaN
# 4             NaN         NaN           NaN
# ..            ...         ...           ...
# 495           NaN         NaN           NaN
# 496           NaN         NaN           NaN
# 497           NaN         NaN           NaN
# 498           NaN         NaN           NaN
# 499           NaN         NaN           NaN
#
# [500 rows x 14 columns]

# %%
ids= []
for i in range(0,500):
   ids.append(random.choice(range(0, 15)))

df['WarehouseID'] = ids
df
# Out:
#      InventoryID InventoryName  InventoryRackNumber  InventoryBatchNumber  \
# 0              1          Inv1                  146                   913
# 1              2          Inv2                  665                    37
# 2              3          Inv3                  481                   799
# 3              4          Inv4                  253                   922
# 4              5          Inv5                  735                   532
# ..           ...           ...                  ...                   ...
# 495          496        Inv496                  850                    84
# 496          497        Inv497                  593                  1473
# 497          498        Inv498                  409                   804
# 498          499        Inv499                   35                   482
# 499          500        Inv500                  692                   979
#
#      Inventory_Initial_Quantity_Ordered  InventoryQuantityUsed  \
# 0                                   230                     39
# 1                                   293                     28
# 2                                   290                     63
# 3                                   223                     56
# 4                                   186                     45
# ..                                  ...                    ...
# 495                                 106                     74
# 496                                 202                     51
# 497                                 101                     11
# 498                                 166                     16
# 499                                 224                      9
#
#      InventoryQuantityinTransit  InventoryQuantityinStock  \
# 0                            21                       191
# 1                            50                       265
# 2                            58                       227
# 3                            44                       167
# 4                            57                       141
# ..                          ...                       ...
# 495                          34                        32
# 496                          56                       151
# 497                          53                        90
# 498                          29                       150
# 499                          21                       215
#
#     InventoryReorderThreshold  InventoryDamagedQuantity InventoryStockStatus  \
# 0                         NaN                         6                  NaN
# 1                         NaN                         6                  NaN
# 2                         NaN                         9                  NaN
# 3                         NaN                         7                  NaN
# 4                         NaN                         8                  NaN
# ..                        ...                       ...                  ...
# 495                       NaN                         9                  NaN
# 496                       NaN                         9                  NaN
# 497                       NaN                         7                  NaN
# 498                       NaN                         5                  NaN
# 499                       NaN                         8                  NaN
#
#     InventoryType  WarehouseID RawMaterialID
# 0             NaN           14           NaN
# 1             NaN            6           NaN
# 2             NaN           12           NaN
# 3             NaN            0           NaN
# 4             NaN            9           NaN
# ..            ...          ...           ...
# 495           NaN            5           NaN
# 496           NaN            5           NaN
# 497           NaN            3           NaN
# 498           NaN           11           NaN
# 499           NaN           13           NaN
#
# [500 rows x 14 columns]

# %%
ids= []
for i in range(0,500):
   ids.append(random.choice(range(0, 65)))

df['RawMaterialID'] = ids
df
# Out:
#      InventoryID InventoryName  InventoryRackNumber  InventoryBatchNumber  \
# 0              1          Inv1                  146                   913
# 1              2          Inv2                  665                    37
# 2              3          Inv3                  481                   799
# 3              4          Inv4                  253                   922
# 4              5          Inv5                  735                   532
# ..           ...           ...                  ...                   ...
# 495          496        Inv496                  850                    84
# 496          497        Inv497                  593                  1473
# 497          498        Inv498                  409                   804
# 498          499        Inv499                   35                   482
# 499          500        Inv500                  692                   979
#
#      Inventory_Initial_Quantity_Ordered  InventoryQuantityUsed  \
# 0                                   230                     39
# 1                                   293                     28
# 2                                   290                     63
# 3                                   223                     56
# 4                                   186                     45
# ..                                  ...                    ...
# 495                                 106                     74
# 496                                 202                     51
# 497                                 101                     11
# 498                                 166                     16
# 499                                 224                      9
#
#      InventoryQuantityinTransit  InventoryQuantityinStock  \
# 0                            21                       191
# 1                            50                       265
# 2                            58                       227
# 3                            44                       167
# 4                            57                       141
# ..                          ...                       ...
# 495                          34                        32
# 496                          56                       151
# 497                          53                        90
# 498                          29                       150
# 499                          21                       215
#
#     InventoryReorderThreshold  InventoryDamagedQuantity InventoryStockStatus  \
# 0                         NaN                         6                  NaN
# 1                         NaN                         6                  NaN
# 2                         NaN                         9                  NaN
# 3                         NaN                         7                  NaN
# 4                         NaN                         8                  NaN
# ..                        ...                       ...                  ...
# 495                       NaN                         9                  NaN
# 496                       NaN                         9                  NaN
# 497                       NaN                         7                  NaN
# 498                       NaN                         5                  NaN
# 499                       NaN                         8                  NaN
#
#     InventoryType  WarehouseID  RawMaterialID
# 0             NaN           14             39
# 1             NaN            6              6
# 2             NaN           12             29
# 3             NaN            0             10
# 4             NaN            9              9
# ..            ...          ...            ...
# 495           NaN            5             42
# 496           NaN            5             40
# 497           NaN            3             10
# 498           NaN           11             14
# 499           NaN           13             29
#
# [500 rows x 14 columns]

# %%
#randomly add InventoryStockStatus
df['InventoryStockStatus'] = random.choices(['In Stock', 'Out of Stock', 'In Transit', 'Damaged'], k=len(df))
df
# Out:
#      InventoryID InventoryName  InventoryRackNumber  InventoryBatchNumber  \
# 0              1          Inv1                  146                   913
# 1              2          Inv2                  665                    37
# 2              3          Inv3                  481                   799
# 3              4          Inv4                  253                   922
# 4              5          Inv5                  735                   532
# ..           ...           ...                  ...                   ...
# 495          496        Inv496                  850                    84
# 496          497        Inv497                  593                  1473
# 497          498        Inv498                  409                   804
# 498          499        Inv499                   35                   482
# 499          500        Inv500                  692                   979
#
#      Inventory_Initial_Quantity_Ordered  InventoryQuantityUsed  \
# 0                                   230                     39
# 1                                   293                     28
# 2                                   290                     63
# 3                                   223                     56
# 4                                   186                     45
# ..                                  ...                    ...
# 495                                 106                     74
# 496                                 202                     51
# 497                                 101                     11
# 498                                 166                     16
# 499                                 224                      9
#
#      InventoryQuantityinTransit  InventoryQuantityinStock  \
# 0                            21                       191
# 1                            50                       265
# 2                            58                       227
# 3                            44                       167
# 4                            57                       141
# ..                          ...                       ...
# 495                          34                        32
# 496                          56                       151
# 497                          53                        90
# 498                          29                       150
# 499                          21                       215
#
#     InventoryReorderThreshold  InventoryDamagedQuantity InventoryStockStatus  \
# 0                         NaN                         6              Damaged
# 1                         NaN                         6              Damaged
# 2                         NaN                         9             In Stock
# 3                         NaN                         7              Damaged
# 4                         NaN                         8              Damaged
# ..                        ...                       ...                  ...
# 495                       NaN                         9         Out of Stock
# 496                       NaN                         9           In Transit
# 497                       NaN                         7           In Transit
# 498                       NaN                         5           In Transit
# 499                       NaN                         8         Out of Stock
#
#     InventoryType  WarehouseID  RawMaterialID
# 0             NaN           14             39
# 1             NaN            6              6
# 2             NaN           12             29
# 3             NaN            0             10
# 4             NaN            9              9
# ..            ...          ...            ...
# 495           NaN            5             42
# 496           NaN            5             40
# 497           NaN            3             10
# 498           NaN           11             14
# 499           NaN           13             29
#
# [500 rows x 14 columns]

# %%
#randomly add InventoryType
df['InventoryType'] = random.choices(['Raw Material', 'Work in Progress', 'Finished Goods'], k=len(df))

# %%
df
# Out:
#      InventoryID InventoryName  InventoryRackNumber  InventoryBatchNumber  \
# 0              1          Inv1                  146                   913
# 1              2          Inv2                  665                    37
# 2              3          Inv3                  481                   799
# 3              4          Inv4                  253                   922
# 4              5          Inv5                  735                   532
# ..           ...           ...                  ...                   ...
# 495          496        Inv496                  850                    84
# 496          497        Inv497                  593                  1473
# 497          498        Inv498                  409                   804
# 498          499        Inv499                   35                   482
# 499          500        Inv500                  692                   979
#
#      Inventory_Initial_Quantity_Ordered  InventoryQuantityUsed  \
# 0                                   230                     39
# 1                                   293                     28
# 2                                   290                     63
# 3                                   223                     56
# 4                                   186                     45
# ..                                  ...                    ...
# 495                                 106                     74
# 496                                 202                     51
# 497                                 101                     11
# 498                                 166                     16
# 499                                 224                      9
#
#      InventoryQuantityinTransit  InventoryQuantityinStock  \
# 0                            21                       191
# 1                            50                       265
# 2                            58                       227
# 3                            44                       167
# 4                            57                       141
# ..                          ...                       ...
# 495                          34                        32
# 496                          56                       151
# 497                          53                        90
# 498                          29                       150
# 499                          21                       215
#
#     InventoryReorderThreshold  InventoryDamagedQuantity InventoryStockStatus  \
# 0                         NaN                         6              Damaged
# 1                         NaN                         6              Damaged
# 2                         NaN                         9             In Stock
# 3                         NaN                         7              Damaged
# 4                         NaN                         8              Damaged
# ..                        ...                       ...                  ...
# 495                       NaN                         9         Out of Stock
# 496                       NaN                         9           In Transit
# 497                       NaN                         7           In Transit
# 498                       NaN                         5           In Transit
# 499                       NaN                         8         Out of Stock
#
#         InventoryType  WarehouseID  RawMaterialID
# 0      Finished Goods           14             39
# 1        Raw Material            6              6
# 2      Finished Goods           12             29
# 3      Finished Goods            0             10
# 4    Work in Progress            9              9
# ..                ...          ...            ...
# 495      Raw Material            5             42
# 496      Raw Material            5             40
# 497      Raw Material            3             10
# 498      Raw Material           11             14
# 499      Raw Material           13             29
#
# [500 rows x 14 columns]
