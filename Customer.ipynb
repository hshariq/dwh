# %%
import pandas as pd
from faker import Faker

fake = Faker(use_weighting=True,locale='en_US')
# Out:
# C:\Users\hamza\AppData\Local\Temp\ipykernel_19320\564241095.py:1: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd

# %%
import pandas as pd

# Define column names for Customers table
Customers_columns = ['CustomerID', 'CustomerName', 'CustomerEmail', 
                     'Customernumber', 'CustomerJoin', 'CustomerLife',
                     'CustomerDOB', 'CustomerAge', 'CustomerGender', 
                     'IsActive', 'CustomerLastPurchaseDate']

# Create an empty DataFrame with the specified column names
df = pd.DataFrame(columns=Customers_columns)

# Display the empty DataFrame
df
# Out:
# Empty DataFrame
# Columns: [CustomerID, CustomerName, CustomerEmail, Customernumber, CustomerJoin, CustomerLife, CustomerDOB, CustomerAge, CustomerGender, IsActive, CustomerLastPurchaseDate]
# Index: []

# %%
ids= []
for i in range(0,350):
   ids.append(i+1)

df['CustomerID'] = ids
df
# Out:
#      CustomerID CustomerName CustomerEmail Customernumber CustomerJoin  \
# 0             1          NaN           NaN            NaN          NaN
# 1             2          NaN           NaN            NaN          NaN
# 2             3          NaN           NaN            NaN          NaN
# 3             4          NaN           NaN            NaN          NaN
# 4             5          NaN           NaN            NaN          NaN
# ..          ...          ...           ...            ...          ...
# 345         346          NaN           NaN            NaN          NaN
# 346         347          NaN           NaN            NaN          NaN
# 347         348          NaN           NaN            NaN          NaN
# 348         349          NaN           NaN            NaN          NaN
# 349         350          NaN           NaN            NaN          NaN
#
#     CustomerLife CustomerDOB CustomerAge CustomerGender IsActive  \
# ...

# %%
import random 
names = []
genders = []
address = []
passwords = []
for i in range(0,350):
    num = random.randint(1,2)
    if (num == 1):
        names.append(fake.first_name_male() +" "+ fake.last_name())
        genders.append("M")
    else:
        names.append(fake.first_name_female() +" "+ fake.last_name())
        genders.append("F")
    # temp = fake.address()
    # temp = temp.replace("\n"," ")
    # temp = temp.replace(",", "")
    # address.append(temp)
    passwords.append(fake.password())

df['CustomerName'] = names
df['CustomerGender'] = genders
# df['player_address'] = address
# df['player_password'] = passwords

df
# Out:
#      CustomerID       CustomerName CustomerEmail Customernumber CustomerJoin  \
# 0             1     Wesley Elliott           NaN            NaN          NaN
# 1             2        Brenda Kemp           NaN            NaN          NaN
# 2             3         Kara Gomez           NaN            NaN          NaN
# 3             4      Bryan Leonard           NaN            NaN          NaN
# 4             5       Paige Garcia           NaN            NaN          NaN
# ..          ...                ...           ...            ...          ...
# 345         346        Carrie Mayo           NaN            NaN          NaN
# 346         347      Michael Salas           NaN            NaN          NaN
# 347         348    Alexander Hines           NaN            NaN          NaN
# 348         349     Isabel Wallace           NaN            NaN          NaN
# 349         350  Elizabeth Barnett           NaN            NaN          NaN
#
# ...

# %%
import random
import string

def generate_email(name):
    domain = "@gmail.com" 
    name = name.replace(' ','')
    random_part = ''.join(random.choices(string.ascii_lowercase + string.digits, k=3))
    return name.lower() + '.' + random_part + domain


df['CustomerEmail'] = df['CustomerName'].apply(generate_email)

df
# Out:
#      CustomerID       CustomerName                   CustomerEmail  \
# 0             1     Wesley Elliott     wesleyelliott.8jd@gmail.com
# 1             2        Brenda Kemp        brendakemp.gze@gmail.com
# 2             3         Kara Gomez         karagomez.d0k@gmail.com
# 3             4      Bryan Leonard      bryanleonard.xix@gmail.com
# 4             5       Paige Garcia       paigegarcia.q9o@gmail.com
# ..          ...                ...                             ...
# 345         346        Carrie Mayo        carriemayo.p09@gmail.com
# 346         347      Michael Salas      michaelsalas.uks@gmail.com
# 347         348    Alexander Hines    alexanderhines.mm1@gmail.com
# 348         349     Isabel Wallace     isabelwallace.8qa@gmail.com
# 349         350  Elizabeth Barnett  elizabethbarnett.rk9@gmail.com
#
#     Customernumber CustomerJoin CustomerLife CustomerDOB CustomerAge  \
# 0              NaN          NaN          NaN         NaN         NaN
# ...

# %%
import random

dates = []
for i in range(0,350):
    mm = random.randint(1,12)
    yy = random.randint(1995,2017)
    dd = random.randint(1,28)
    dates.append(f"{dd}-{mm}-{yy}")

df['CustomerDOB'] = dates

df
# Out:
#      CustomerID       CustomerName                   CustomerEmail  \
# 0             1     Wesley Elliott     wesleyelliott.8jd@gmail.com
# 1             2        Brenda Kemp        brendakemp.gze@gmail.com
# 2             3         Kara Gomez         karagomez.d0k@gmail.com
# 3             4      Bryan Leonard      bryanleonard.xix@gmail.com
# 4             5       Paige Garcia       paigegarcia.q9o@gmail.com
# ..          ...                ...                             ...
# 345         346        Carrie Mayo        carriemayo.p09@gmail.com
# 346         347      Michael Salas      michaelsalas.uks@gmail.com
# 347         348    Alexander Hines    alexanderhines.mm1@gmail.com
# 348         349     Isabel Wallace     isabelwallace.8qa@gmail.com
# 349         350  Elizabeth Barnett  elizabethbarnett.rk9@gmail.com
#
#     Customernumber CustomerJoin CustomerLife CustomerDOB CustomerAge  \
# 0              NaN          NaN          NaN  10-10-1997         NaN
# ...

# %%
import random
phone_number = []

for i in range(0,350):
    area_code = random.randint(100, 999)
    prefix = random.randint(100, 999)
    line_number = random.randint(1000, 9999)
    phone_number.append(f"{area_code}-{prefix}-{line_number}")

df['Customernumber'] = phone_number
df
# Out:
#      CustomerID       CustomerName                   CustomerEmail  \
# 0             1     Wesley Elliott     wesleyelliott.8jd@gmail.com
# 1             2        Brenda Kemp        brendakemp.gze@gmail.com
# 2             3         Kara Gomez         karagomez.d0k@gmail.com
# 3             4      Bryan Leonard      bryanleonard.xix@gmail.com
# 4             5       Paige Garcia       paigegarcia.q9o@gmail.com
# ..          ...                ...                             ...
# 345         346        Carrie Mayo        carriemayo.p09@gmail.com
# 346         347      Michael Salas      michaelsalas.uks@gmail.com
# 347         348    Alexander Hines    alexanderhines.mm1@gmail.com
# 348         349     Isabel Wallace     isabelwallace.8qa@gmail.com
# 349         350  Elizabeth Barnett  elizabethbarnett.rk9@gmail.com
#
#     Customernumber CustomerJoin CustomerLife CustomerDOB CustomerAge  \
# 0     142-282-4542          NaN          NaN  10-10-1997         NaN
# ...

# %%
import random

dates = []
for i in range(0,350):
    mm = random.randint(1,12)
    yy = random.randint(2015,2024)
    dd = random.randint(1,28)
    dates.append(f"{dd}-{mm}-{yy}")

df['CustomerJoin'] = dates

df
# Out:
#      CustomerID       CustomerName                   CustomerEmail  \
# 0             1     Wesley Elliott     wesleyelliott.8jd@gmail.com
# 1             2        Brenda Kemp        brendakemp.gze@gmail.com
# 2             3         Kara Gomez         karagomez.d0k@gmail.com
# 3             4      Bryan Leonard      bryanleonard.xix@gmail.com
# 4             5       Paige Garcia       paigegarcia.q9o@gmail.com
# ..          ...                ...                             ...
# 345         346        Carrie Mayo        carriemayo.p09@gmail.com
# 346         347      Michael Salas      michaelsalas.uks@gmail.com
# 347         348    Alexander Hines    alexanderhines.mm1@gmail.com
# 348         349     Isabel Wallace     isabelwallace.8qa@gmail.com
# 349         350  Elizabeth Barnett  elizabethbarnett.rk9@gmail.com
#
#     Customernumber CustomerJoin CustomerLife CustomerDOB CustomerAge  \
# 0     142-282-4542    2-12-2017          NaN  10-10-1997         NaN
# ...

# %%
from datetime import datetime

current_year = datetime.now().year
df['CustomerLife'] = current_year - pd.to_datetime(df['CustomerJoin'], dayfirst=True).dt.year

# %%
from datetime import datetime

current_year = datetime.now().year
df['CustomerAge'] = current_year - pd.to_datetime(df['CustomerDOB']).dt.year
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[11], line 4
#       1 from datetime import datetime
#       3 current_year = datetime.now().year
# ----> 4 df['CustomerAge'] = current_year - pd.to_datetime(df['CustomerDOB']).dt.year
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\pandas\core\tools\datetimes.py:1067, in to_datetime(arg, errors, dayfirst, yearfirst, utc, format, exact, unit, infer_datetime_format, origin, cache)
#    1065         result = arg.map(cache_array)
#    1066     else:
# -> 1067         values = convert_listlike(arg._values, format)
#    1068         result = arg._constructor(values, index=arg.index, name=arg.name)
#    1069 elif isinstance(arg, (ABCDataFrame, abc.MutableMapping)):
#
# ...

# %%
df
# Out:
#      CustomerID       CustomerName                   CustomerEmail  \
# 0             1     Wesley Elliott     wesleyelliott.8jd@gmail.com
# 1             2        Brenda Kemp        brendakemp.gze@gmail.com
# 2             3         Kara Gomez         karagomez.d0k@gmail.com
# 3             4      Bryan Leonard      bryanleonard.xix@gmail.com
# 4             5       Paige Garcia       paigegarcia.q9o@gmail.com
# ..          ...                ...                             ...
# 345         346        Carrie Mayo        carriemayo.p09@gmail.com
# 346         347      Michael Salas      michaelsalas.uks@gmail.com
# 347         348    Alexander Hines    alexanderhines.mm1@gmail.com
# 348         349     Isabel Wallace     isabelwallace.8qa@gmail.com
# 349         350  Elizabeth Barnett  elizabethbarnett.rk9@gmail.com
#
#     Customernumber CustomerJoin  CustomerLife CustomerDOB CustomerAge  \
# 0     142-282-4542    2-12-2017             7  10-10-1997         NaN
# ...

# %%
for i in range(350):
    a = random.randint(0, 1)
    df.loc[i, 'IsActive'] = a
    
# df['IsTemperatureControlled']

# %%
df
# Out:
#      CustomerID       CustomerName                   CustomerEmail  \
# 0             1     Wesley Elliott     wesleyelliott.8jd@gmail.com
# 1             2        Brenda Kemp        brendakemp.gze@gmail.com
# 2             3         Kara Gomez         karagomez.d0k@gmail.com
# 3             4      Bryan Leonard      bryanleonard.xix@gmail.com
# 4             5       Paige Garcia       paigegarcia.q9o@gmail.com
# ..          ...                ...                             ...
# 345         346        Carrie Mayo        carriemayo.p09@gmail.com
# 346         347      Michael Salas      michaelsalas.uks@gmail.com
# 347         348    Alexander Hines    alexanderhines.mm1@gmail.com
# 348         349     Isabel Wallace     isabelwallace.8qa@gmail.com
# 349         350  Elizabeth Barnett  elizabethbarnett.rk9@gmail.com
#
#     Customernumber CustomerJoin  CustomerLife CustomerDOB CustomerAge  \
# 0     142-282-4542    2-12-2017             7  10-10-1997         NaN
# ...

# %%
dates = []
for i in range(0,350):
    mm = random.randint(1,12)
    yy = random.randint(2022,2024)
    dd = random.randint(1,28)
    dates.append(f"{dd}-{mm}-{yy}")

df['CustomerLastPurchaseDate'] = dates

df
# Out:
#      CustomerID       CustomerName                   CustomerEmail  \
# 0             1     Wesley Elliott     wesleyelliott.8jd@gmail.com
# 1             2        Brenda Kemp        brendakemp.gze@gmail.com
# 2             3         Kara Gomez         karagomez.d0k@gmail.com
# 3             4      Bryan Leonard      bryanleonard.xix@gmail.com
# 4             5       Paige Garcia       paigegarcia.q9o@gmail.com
# ..          ...                ...                             ...
# 345         346        Carrie Mayo        carriemayo.p09@gmail.com
# 346         347      Michael Salas      michaelsalas.uks@gmail.com
# 347         348    Alexander Hines    alexanderhines.mm1@gmail.com
# 348         349     Isabel Wallace     isabelwallace.8qa@gmail.com
# 349         350  Elizabeth Barnett  elizabethbarnett.rk9@gmail.com
#
#     Customernumber CustomerJoin  CustomerLife CustomerDOB CustomerAge  \
# 0     142-282-4542    2-12-2017             7  10-10-1997         NaN
# ...

# %%
df.to_csv("Customers.csv")
