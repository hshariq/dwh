# %%
import pandas as pd

# Define column names for WarehouseManagerRequest table
WarehouseManagerRequest_columns = ['RequestID', 'ManagerID', 'WarehouseID', 'InventoryID', 
                                   'QuantityRequested', 'RequestStatus', 'RequestDate']

# Create an empty DataFrame with the specified column names
df = pd.DataFrame(columns=WarehouseManagerRequest_columns)

# Display the empty DataFrame
df
# Out:
# C:\Users\hamza\AppData\Local\Temp\ipykernel_1804\557708948.py:1: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd
# Empty DataFrame
# Columns: [RequestID, ManagerID, WarehouseID, InventoryID, QuantityRequested, RequestStatus, RequestDate]
# Index: []

# %%
import pandas as pd
from faker import Faker

fake = Faker(use_weighting=True,locale='en_US')

# %%
ids= []
for i in range(0,100):
   ids.append(i+1)

df['RequestID'] = ids
df
# Out:
#     RequestID ManagerID WarehouseID InventoryID QuantityRequested  \
# 0           1       NaN         NaN         NaN               NaN
# 1           2       NaN         NaN         NaN               NaN
# 2           3       NaN         NaN         NaN               NaN
# 3           4       NaN         NaN         NaN               NaN
# 4           5       NaN         NaN         NaN               NaN
# ..        ...       ...         ...         ...               ...
# 95         96       NaN         NaN         NaN               NaN
# 96         97       NaN         NaN         NaN               NaN
# 97         98       NaN         NaN         NaN               NaN
# 98         99       NaN         NaN         NaN               NaN
# 99        100       NaN         NaN         NaN               NaN
#
#    RequestStatus RequestDate
# 0            NaN         NaN
# 1            NaN         NaN
# 2            NaN         NaN
# 3            NaN         NaN
# ...

# %%
import random

# %%
ids= []
for i in range(0,100):
   ids.append(random.choice(range(0, 15)))

df['ManagerID'] = ids
df
# Out:
#     RequestID  ManagerID WarehouseID InventoryID QuantityRequested  \
# 0           1          6         NaN         NaN               NaN
# 1           2          2         NaN         NaN               NaN
# 2           3          6         NaN         NaN               NaN
# 3           4         14         NaN         NaN               NaN
# 4           5         10         NaN         NaN               NaN
# ..        ...        ...         ...         ...               ...
# 95         96          4         NaN         NaN               NaN
# 96         97         10         NaN         NaN               NaN
# 97         98         14         NaN         NaN               NaN
# 98         99          2         NaN         NaN               NaN
# 99        100          5         NaN         NaN               NaN
#
#    RequestStatus RequestDate
# 0            NaN         NaN
# 1            NaN         NaN
# 2            NaN         NaN
# 3            NaN         NaN
# ...

# %%
ids= []
for i in range(0,100):
   ids.append(random.choice(range(0, 15)))

df['WarehouseID'] = ids
df
# Out:
#     RequestID  ManagerID  WarehouseID InventoryID QuantityRequested  \
# 0           1          6            8         NaN               NaN
# 1           2          2            4         NaN               NaN
# 2           3          6            2         NaN               NaN
# 3           4         14            7         NaN               NaN
# 4           5         10            9         NaN               NaN
# ..        ...        ...          ...         ...               ...
# 95         96          4            9         NaN               NaN
# 96         97         10            6         NaN               NaN
# 97         98         14            7         NaN               NaN
# 98         99          2           13         NaN               NaN
# 99        100          5            6         NaN               NaN
#
#    RequestStatus RequestDate
# 0            NaN         NaN
# 1            NaN         NaN
# 2            NaN         NaN
# 3            NaN         NaN
# ...

# %%
ids= []
for i in range(0,100):
   ids.append(random.choice(range(0, 500)))

df['InventoryID'] = ids
df
# Out:
#     RequestID  ManagerID  WarehouseID  InventoryID QuantityRequested  \
# 0           1          6            8          259               NaN
# 1           2          2            4           95               NaN
# 2           3          6            2          389               NaN
# 3           4         14            7          442               NaN
# 4           5         10            9          368               NaN
# ..        ...        ...          ...          ...               ...
# 95         96          4            9          319               NaN
# 96         97         10            6          164               NaN
# 97         98         14            7           61               NaN
# 98         99          2           13          299               NaN
# 99        100          5            6          189               NaN
#
#    RequestStatus RequestDate
# 0            NaN         NaN
# 1            NaN         NaN
# 2            NaN         NaN
# ...

# %%
#QuantityRequested column is a random number between 1 and 100
ids= []
for i in range(0,100):
   ids.append(random.choice(range(1, 250)))

df['QuantityRequested'] = ids
df
# Out:
#     RequestID  ManagerID  WarehouseID  InventoryID  QuantityRequested  \
# 0           1          6            8          259                236
# 1           2          2            4           95                221
# 2           3          6            2          389                150
# 3           4         14            7          442                 90
# 4           5         10            9          368                235
# ..        ...        ...          ...          ...                ...
# 95         96          4            9          319                 18
# 96         97         10            6          164                181
# 97         98         14            7           61                 36
# 98         99          2           13          299                206
# 99        100          5            6          189                134
#
#    RequestStatus RequestDate
# 0            NaN         NaN
# 1            NaN         NaN
# 2            NaN         NaN
# ...

# %%
#ReestStatus is a random status from the list
ids= []
for i in range(0,100):
   ids.append(random.choice(['Pending', 'Approved', 'Rejected']))
   
df['RequestStatus'] = ids
df
# Out:
#     RequestID  ManagerID  WarehouseID  InventoryID  QuantityRequested  \
# 0           1          6            8          259                236
# 1           2          2            4           95                221
# 2           3          6            2          389                150
# 3           4         14            7          442                 90
# 4           5         10            9          368                235
# ..        ...        ...          ...          ...                ...
# 95         96          4            9          319                 18
# 96         97         10            6          164                181
# 97         98         14            7           61                 36
# 98         99          2           13          299                206
# 99        100          5            6          189                134
#
#    RequestStatus RequestDate
# 0        Pending         NaN
# 1       Rejected         NaN
# 2       Rejected         NaN
# ...

# %%
import random
import datetime

# Generate random dates
dates = []
current_date = datetime.datetime.now()

for i in range(0, 100):
    mm = random.randint(1, current_date.month)
    yy = random.randint(2022, current_date.year)
    dd = random.randint(1, 28)
    date = datetime.datetime(yy, mm, dd)
    
    dates.append(date.strftime("%d-%m-%Y"))

df['RequestDate'] = dates

df
# Out:
#     RequestID  ManagerID  WarehouseID  InventoryID  QuantityRequested  \
# 0           1          6            8          259                236
# 1           2          2            4           95                221
# 2           3          6            2          389                150
# 3           4         14            7          442                 90
# 4           5         10            9          368                235
# ..        ...        ...          ...          ...                ...
# 95         96          4            9          319                 18
# 96         97         10            6          164                181
# 97         98         14            7           61                 36
# 98         99          2           13          299                206
# 99        100          5            6          189                134
#
#    RequestStatus RequestDate
# 0        Pending  13-02-2022
# 1       Rejected  17-01-2022
# 2       Rejected  16-02-2022
# ...

# %%
df.to_csv('Data/WarehouseManagerRequest.csv', index=False)
