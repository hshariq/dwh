# %%
import pandas as pd

# Define column names for Production table
Production_columns = ['ProductionID', 'ProductionStartDate',
                      'ProductionEndDate', 'Status', 'WarehouseID',
                      'PManagerID']

# Create an empty DataFrame with the specified column names
df = pd.DataFrame(columns=Production_columns)

# Display the empty DataFrame
df
# Out:
# C:\Users\hamza\AppData\Local\Temp\ipykernel_9056\1306666090.py:1: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd
# Empty DataFrame
# Columns: [ProductionID, ProductionStartDate, ProductionEndDate, Status, WarehouseID, PManagerID]
# Index: []

# %%
import pandas as pd
from faker import Faker

fake = Faker(use_weighting=True,locale='en_US')

# %%
ids= []
for i in range(0,500):
   ids.append(i+1)

df['ProductionID'] = ids
df
# Out:
#      ProductionID ProductionStartDate ProductionEndDate Status WarehouseID  \
# 0               1                 NaN               NaN    NaN         NaN
# 1               2                 NaN               NaN    NaN         NaN
# 2               3                 NaN               NaN    NaN         NaN
# 3               4                 NaN               NaN    NaN         NaN
# 4               5                 NaN               NaN    NaN         NaN
# ..            ...                 ...               ...    ...         ...
# 495           496                 NaN               NaN    NaN         NaN
# 496           497                 NaN               NaN    NaN         NaN
# 497           498                 NaN               NaN    NaN         NaN
# 498           499                 NaN               NaN    NaN         NaN
# 499           500                 NaN               NaN    NaN         NaN
#
#     PManagerID
# 0          NaN
# 1          NaN
# 2          NaN
# ...

# %%
#start date
start_date = []
for _ in range(500):
    start_date.append(fake.date_between(start_date='-1y', end_date='today'))
df['ProductionStartDate'] = start_date
df
# Out:
#      ProductionID ProductionStartDate ProductionEndDate Status WarehouseID  \
# 0               1          2023-09-01               NaN    NaN         NaN
# 1               2          2023-06-20               NaN    NaN         NaN
# 2               3          2023-12-16               NaN    NaN         NaN
# 3               4          2023-05-25               NaN    NaN         NaN
# 4               5          2023-07-17               NaN    NaN         NaN
# ..            ...                 ...               ...    ...         ...
# 495           496          2023-04-12               NaN    NaN         NaN
# 496           497          2023-08-14               NaN    NaN         NaN
# 497           498          2023-06-16               NaN    NaN         NaN
# 498           499          2023-11-17               NaN    NaN         NaN
# 499           500          2023-10-10               NaN    NaN         NaN
#
#     PManagerID
# 0          NaN
# 1          NaN
# 2          NaN
# ...

# %%
#end date a few days later then start date
end_date = []
for _ in range(500):
    end_date.append(fake.date_between(start_date=df['ProductionStartDate'][_], end_date='+1y'))
df['ProductionEndDate'] = end_date
df
# Out:
#      ProductionID ProductionStartDate ProductionEndDate Status WarehouseID  \
# 0               1          2023-09-01        2024-07-22    NaN         NaN
# 1               2          2023-06-20        2023-08-13    NaN         NaN
# 2               3          2023-12-16        2024-12-30    NaN         NaN
# 3               4          2023-05-25        2023-11-03    NaN         NaN
# 4               5          2023-07-17        2023-09-02    NaN         NaN
# ..            ...                 ...               ...    ...         ...
# 495           496          2023-04-12        2024-03-12    NaN         NaN
# 496           497          2023-08-14        2025-02-13    NaN         NaN
# 497           498          2023-06-16        2023-10-02    NaN         NaN
# 498           499          2023-11-17        2023-12-07    NaN         NaN
# 499           500          2023-10-10        2024-02-21    NaN         NaN
#
#     PManagerID
# 0          NaN
# 1          NaN
# 2          NaN
# ...

# %%
#status ranomly
status = []
for _ in range(500):
    status.append(fake.random_element(elements=('Active', 'Inactive')))
df['Status'] = status
df
# Out:
#      ProductionID ProductionStartDate ProductionEndDate    Status WarehouseID  \
# 0               1          2023-09-01        2024-07-22  Inactive         NaN
# 1               2          2023-06-20        2023-08-13  Inactive         NaN
# 2               3          2023-12-16        2024-12-30  Inactive         NaN
# 3               4          2023-05-25        2023-11-03    Active         NaN
# 4               5          2023-07-17        2023-09-02    Active         NaN
# ..            ...                 ...               ...       ...         ...
# 495           496          2023-04-12        2024-03-12    Active         NaN
# 496           497          2023-08-14        2025-02-13    Active         NaN
# 497           498          2023-06-16        2023-10-02  Inactive         NaN
# 498           499          2023-11-17        2023-12-07    Active         NaN
# 499           500          2023-10-10        2024-02-21    Active         NaN
#
#     PManagerID
# 0          NaN
# ...

# %%
#warehouse id 1-15 randomly
warehouse_id = []
for _ in range(500):
    warehouse_id.append(fake.random_int(min=1, max=15))
df['WarehouseID'] = warehouse_id
df
# Out:
#      ProductionID ProductionStartDate ProductionEndDate    Status  \
# 0               1          2023-09-01        2024-07-22  Inactive
# 1               2          2023-06-20        2023-08-13  Inactive
# 2               3          2023-12-16        2024-12-30  Inactive
# 3               4          2023-05-25        2023-11-03    Active
# 4               5          2023-07-17        2023-09-02    Active
# ..            ...                 ...               ...       ...
# 495           496          2023-04-12        2024-03-12    Active
# 496           497          2023-08-14        2025-02-13    Active
# 497           498          2023-06-16        2023-10-02  Inactive
# 498           499          2023-11-17        2023-12-07    Active
# 499           500          2023-10-10        2024-02-21    Active
#
#      WarehouseID PManagerID
# 0             13        NaN
# 1              6        NaN
# 2             12        NaN
# 3             12        NaN
# ...

# %%
#pmanagerID randomly 1-10
pmanager_id = []
for _ in range(500):
    pmanager_id.append(fake.random_int(min=1, max=10))
df['PManagerID'] = pmanager_id
df
# Out:
#      ProductionID ProductionStartDate ProductionEndDate    Status  \
# 0               1          2023-09-01        2024-07-22  Inactive
# 1               2          2023-06-20        2023-08-13  Inactive
# 2               3          2023-12-16        2024-12-30  Inactive
# 3               4          2023-05-25        2023-11-03    Active
# 4               5          2023-07-17        2023-09-02    Active
# ..            ...                 ...               ...       ...
# 495           496          2023-04-12        2024-03-12    Active
# 496           497          2023-08-14        2025-02-13    Active
# 497           498          2023-06-16        2023-10-02  Inactive
# 498           499          2023-11-17        2023-12-07    Active
# 499           500          2023-10-10        2024-02-21    Active
#
#      WarehouseID  PManagerID
# 0             13           1
# 1              6           5
# 2             12           1
# 3             12           2
# ...

# %%
df.to_csv('Data/Production.csv',index=False)
