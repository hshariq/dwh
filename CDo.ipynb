# %%
import pandas as pd

# Define column names for CustomerDeliveryOrder table
CustomerDeliveryOrder_columns = ['DeliveryID', 'DeliveredDate',
                                 'DeliveryDuration', 'DeliveryStatus',
                                 'QuantityDelivered', 'PaymentDate',
                                 'PaymentMethod', 'PaymentStatus',
                                 'IsOrderCompleted', 'OrderID',
                                 'CLocID']

# Create an empty DataFrame with the specified column names
df = pd.DataFrame(columns=CustomerDeliveryOrder_columns)

# Display the empty DataFrame
print(df)
# Out:
# Empty DataFrame
# Columns: [DeliveryID, DeliveredDate, DeliveryDuration, DeliveryStatus, QuantityDelivered, PaymentDate, PaymentMethod, PaymentStatus, IsOrderCompleted, OrderID, CLocID]
# Index: []
# C:\Users\hamza\AppData\Local\Temp\ipykernel_21200\1094584163.py:1: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd

# %%
import pandas as pd
from faker import Faker

fake = Faker(use_weighting=True,locale='en_US')

# %%
ids= []
import random
for i in range(0,500):
   ids.append(i+1)
df['DeliveryID'] = ids
df
# Out:
#      DeliveryID DeliveredDate DeliveryDuration DeliveryStatus  \
# 0             1           NaN              NaN            NaN
# 1             2           NaN              NaN            NaN
# 2             3           NaN              NaN            NaN
# 3             4           NaN              NaN            NaN
# 4             5           NaN              NaN            NaN
# ..          ...           ...              ...            ...
# 495         496           NaN              NaN            NaN
# 496         497           NaN              NaN            NaN
# 497         498           NaN              NaN            NaN
# 498         499           NaN              NaN            NaN
# 499         500           NaN              NaN            NaN
#
#     QuantityDelivered PaymentDate PaymentMethod PaymentStatus  \
# 0                 NaN         NaN           NaN           NaN
# 1                 NaN         NaN           NaN           NaN
# 2                 NaN         NaN           NaN           NaN
# 3                 NaN         NaN           NaN           NaN
# 4                 NaN         NaN           NaN           NaN
# ..                ...         ...           ...           ...
# 495               NaN         NaN           NaN           NaN
# 496               NaN         NaN           NaN           NaN
# 497               NaN         NaN           NaN           NaN
# 498               NaN         NaN           NaN           NaN
# 499               NaN         NaN           NaN           NaN
#
#     IsOrderCompleted OrderID CLocID
# 0                NaN     NaN    NaN
# 1                NaN     NaN    NaN
# 2                NaN     NaN    NaN
# 3                NaN     NaN    NaN
# 4                NaN     NaN    NaN
# ..               ...     ...    ...
# 495              NaN     NaN    NaN
# 496              NaN     NaN    NaN
# 497              NaN     NaN    NaN
# 498              NaN     NaN    NaN
# 499              NaN     NaN    NaN
#
# [500 rows x 11 columns]

# %%
q= []
import random
for i in range(0,500):
    a= random.randint(1,15)
    if a<5:
        q.append(3)
    elif a<10:
        q.append(5)
    else:
        q.append(10)
        
df['DeliveryDuration'] = q
df
# Out:
#      DeliveryID DeliveredDate  DeliveryDuration DeliveryStatus  \
# 0             1           NaN                10            NaN
# 1             2           NaN                 3            NaN
# 2             3           NaN                10            NaN
# 3             4           NaN                 3            NaN
# 4             5           NaN                 3            NaN
# ..          ...           ...               ...            ...
# 495         496           NaN                10            NaN
# 496         497           NaN                10            NaN
# 497         498           NaN                10            NaN
# 498         499           NaN                 5            NaN
# 499         500           NaN                10            NaN
#
#     QuantityDelivered PaymentDate PaymentMethod PaymentStatus  \
# 0                 NaN         NaN           NaN           NaN
# 1                 NaN         NaN           NaN           NaN
# 2                 NaN         NaN           NaN           NaN
# 3                 NaN         NaN           NaN           NaN
# 4                 NaN         NaN           NaN           NaN
# ..                ...         ...           ...           ...
# 495               NaN         NaN           NaN           NaN
# 496               NaN         NaN           NaN           NaN
# 497               NaN         NaN           NaN           NaN
# 498               NaN         NaN           NaN           NaN
# 499               NaN         NaN           NaN           NaN
#
#     IsOrderCompleted OrderID CLocID
# 0                NaN     NaN    NaN
# 1                NaN     NaN    NaN
# 2                NaN     NaN    NaN
# 3                NaN     NaN    NaN
# 4                NaN     NaN    NaN
# ..               ...     ...    ...
# 495              NaN     NaN    NaN
# 496              NaN     NaN    NaN
# 497              NaN     NaN    NaN
# 498              NaN     NaN    NaN
# 499              NaN     NaN    NaN
#
# [500 rows x 11 columns]

# %%
import random

dates = []
for i in range(0,500):
    mm = random.randint(1,12)
    yy = random.randint(2014,2024)
    dd = random.randint(1,28)
    dates.append(f"{dd}-{mm}-{yy}")

df['DeliveredDate'] = dates

df
# Out:
#      DeliveryID DeliveredDate  DeliveryDuration DeliveryStatus  \
# 0             1      2-1-2015                10            NaN
# 1             2      6-4-2014                 3            NaN
# 2             3     5-11-2018                10            NaN
# 3             4      4-4-2020                 3            NaN
# 4             5    15-10-2015                 3            NaN
# ..          ...           ...               ...            ...
# 495         496     21-1-2015                10            NaN
# 496         497     20-5-2015                10            NaN
# 497         498      9-2-2014                10            NaN
# 498         499     13-2-2019                 5            NaN
# 499         500      7-6-2024                10            NaN
#
#     QuantityDelivered PaymentDate PaymentMethod PaymentStatus  \
# 0                 NaN         NaN           NaN           NaN
# 1                 NaN         NaN           NaN           NaN
# 2                 NaN         NaN           NaN           NaN
# 3                 NaN         NaN           NaN           NaN
# 4                 NaN         NaN           NaN           NaN
# ..                ...         ...           ...           ...
# 495               NaN         NaN           NaN           NaN
# 496               NaN         NaN           NaN           NaN
# 497               NaN         NaN           NaN           NaN
# 498               NaN         NaN           NaN           NaN
# 499               NaN         NaN           NaN           NaN
#
#     IsOrderCompleted OrderID CLocID
# 0                NaN     NaN    NaN
# 1                NaN     NaN    NaN
# 2                NaN     NaN    NaN
# 3                NaN     NaN    NaN
# 4                NaN     NaN    NaN
# ..               ...     ...    ...
# 495              NaN     NaN    NaN
# 496              NaN     NaN    NaN
# 497              NaN     NaN    NaN
# 498              NaN     NaN    NaN
# 499              NaN     NaN    NaN
#
# [500 rows x 11 columns]

# %%
q= []
for i in range(0,500):
    a= random.randint(1,15)
    if a<7:
        q.append('Shipped')
    else:
        q.append('Delivered')

df['DeliveryStatus'] = q
df
# Out:
#      DeliveryID DeliveredDate  DeliveryDuration DeliveryStatus  \
# 0             1      2-1-2015                10      Delivered
# 1             2      6-4-2014                 3        Shipped
# 2             3     5-11-2018                10        Shipped
# 3             4      4-4-2020                 3      Delivered
# 4             5    15-10-2015                 3        Shipped
# ..          ...           ...               ...            ...
# 495         496     21-1-2015                10        Shipped
# 496         497     20-5-2015                10      Delivered
# 497         498      9-2-2014                10      Delivered
# 498         499     13-2-2019                 5      Delivered
# 499         500      7-6-2024                10      Delivered
#
#     QuantityDelivered PaymentDate PaymentMethod PaymentStatus  \
# 0                 NaN         NaN           NaN           NaN
# 1                 NaN         NaN           NaN           NaN
# 2                 NaN         NaN           NaN           NaN
# 3                 NaN         NaN           NaN           NaN
# 4                 NaN         NaN           NaN           NaN
# ..                ...         ...           ...           ...
# 495               NaN         NaN           NaN           NaN
# 496               NaN         NaN           NaN           NaN
# 497               NaN         NaN           NaN           NaN
# 498               NaN         NaN           NaN           NaN
# 499               NaN         NaN           NaN           NaN
#
#     IsOrderCompleted OrderID CLocID
# 0                NaN     NaN    NaN
# 1                NaN     NaN    NaN
# 2                NaN     NaN    NaN
# 3                NaN     NaN    NaN
# 4                NaN     NaN    NaN
# ..               ...     ...    ...
# 495              NaN     NaN    NaN
# 496              NaN     NaN    NaN
# 497              NaN     NaN    NaN
# 498              NaN     NaN    NaN
# 499              NaN     NaN    NaN
#
# [500 rows x 11 columns]

# %%
import random
q= []
for i in range(0,500):
    a= random.randint(1,15)
    q.append(a)

df['QuantityDelivered'] = q
df
# Out:
#      DeliveryID DeliveredDate  DeliveryDuration DeliveryStatus  \
# 0             1      2-1-2015                10      Delivered
# 1             2      6-4-2014                 3        Shipped
# 2             3     5-11-2018                10        Shipped
# 3             4      4-4-2020                 3      Delivered
# 4             5    15-10-2015                 3        Shipped
# ..          ...           ...               ...            ...
# 495         496     21-1-2015                10        Shipped
# 496         497     20-5-2015                10      Delivered
# 497         498      9-2-2014                10      Delivered
# 498         499     13-2-2019                 5      Delivered
# 499         500      7-6-2024                10      Delivered
#
#      QuantityDelivered PaymentDate PaymentMethod PaymentStatus  \
# 0                   11         NaN           NaN           NaN
# 1                    1         NaN           NaN           NaN
# 2                   10         NaN           NaN           NaN
# 3                    5         NaN           NaN           NaN
# 4                    8         NaN           NaN           NaN
# ..                 ...         ...           ...           ...
# 495                  6         NaN           NaN           NaN
# 496                  7         NaN           NaN           NaN
# 497                  3         NaN           NaN           NaN
# 498                  1         NaN           NaN           NaN
# 499                  1         NaN           NaN           NaN
#
#     IsOrderCompleted OrderID CLocID
# 0                NaN     NaN    NaN
# 1                NaN     NaN    NaN
# 2                NaN     NaN    NaN
# 3                NaN     NaN    NaN
# 4                NaN     NaN    NaN
# ..               ...     ...    ...
# 495              NaN     NaN    NaN
# 496              NaN     NaN    NaN
# 497              NaN     NaN    NaN
# 498              NaN     NaN    NaN
# 499              NaN     NaN    NaN
#
# [500 rows x 11 columns]

# %%
from datetime import datetime, timedelta
# Convert the delivered dates to datetime objects
delivered_dates = [datetime.strptime(date, '%d-%m-%Y') for date in df['DeliveredDate']]

# Generate payment dates ±10 days from the delivered dates
payment_dates = [date + timedelta(days=random.randint(-10, 10)) for date in delivered_dates]

# Convert the payment dates back to the desired format
payment_dates = [date.strftime('%d-%m-%Y') for date in payment_dates]

# Assign the payment dates to the 'PaymentDate' column in the dataframe
df['PaymentDate'] = payment_dates

# Display the updated dataframe
df
# Out:
#      DeliveryID DeliveredDate  DeliveryDuration DeliveryStatus  \
# 0             1      2-1-2015                10      Delivered
# 1             2      6-4-2014                 3        Shipped
# 2             3     5-11-2018                10        Shipped
# 3             4      4-4-2020                 3      Delivered
# 4             5    15-10-2015                 3        Shipped
# ..          ...           ...               ...            ...
# 495         496     21-1-2015                10        Shipped
# 496         497     20-5-2015                10      Delivered
# 497         498      9-2-2014                10      Delivered
# 498         499     13-2-2019                 5      Delivered
# 499         500      7-6-2024                10      Delivered
#
#      QuantityDelivered PaymentDate PaymentMethod PaymentStatus  \
# 0                   11  05-01-2015           NaN           NaN
# 1                    1  15-04-2014           NaN           NaN
# 2                   10  06-11-2018           NaN           NaN
# 3                    5  11-04-2020           NaN           NaN
# 4                    8  15-10-2015           NaN           NaN
# ..                 ...         ...           ...           ...
# 495                  6  31-01-2015           NaN           NaN
# 496                  7  10-05-2015           NaN           NaN
# 497                  3  04-02-2014           NaN           NaN
# 498                  1  22-02-2019           NaN           NaN
# 499                  1  31-05-2024           NaN           NaN
#
#     IsOrderCompleted OrderID CLocID
# 0                NaN     NaN    NaN
# 1                NaN     NaN    NaN
# 2                NaN     NaN    NaN
# 3                NaN     NaN    NaN
# 4                NaN     NaN    NaN
# ..               ...     ...    ...
# 495              NaN     NaN    NaN
# 496              NaN     NaN    NaN
# 497              NaN     NaN    NaN
# 498              NaN     NaN    NaN
# 499              NaN     NaN    NaN
#
# [500 rows x 11 columns]

# %%
p=[]
for i in range(0,500):
    p.append(random.choice(['Cash','Card','Paypal']))
df['PaymentMethod'] = p

# %%
q= []
for i in range(0,500):
    a= random.randint(1,15)
    if a<7:
        q.append('Paid')
    else:
        q.append('Pending')

df['PaymentStatus'] = q
df
# Out:
#      DeliveryID DeliveredDate  DeliveryDuration DeliveryStatus  \
# 0             1      2-1-2015                10      Delivered
# 1             2      6-4-2014                 3        Shipped
# 2             3     5-11-2018                10        Shipped
# 3             4      4-4-2020                 3      Delivered
# 4             5    15-10-2015                 3        Shipped
# ..          ...           ...               ...            ...
# 495         496     21-1-2015                10        Shipped
# 496         497     20-5-2015                10      Delivered
# 497         498      9-2-2014                10      Delivered
# 498         499     13-2-2019                 5      Delivered
# 499         500      7-6-2024                10      Delivered
#
#      QuantityDelivered PaymentDate PaymentMethod PaymentStatus  \
# 0                   11  05-01-2015          Card       Pending
# 1                    1  15-04-2014        Paypal       Pending
# 2                   10  06-11-2018          Card       Pending
# 3                    5  11-04-2020          Cash       Pending
# 4                    8  15-10-2015        Paypal       Pending
# ..                 ...         ...           ...           ...
# 495                  6  31-01-2015        Paypal          Paid
# 496                  7  10-05-2015          Card       Pending
# 497                  3  04-02-2014          Cash          Paid
# 498                  1  22-02-2019          Card       Pending
# 499                  1  31-05-2024        Paypal          Paid
#
#     IsOrderCompleted OrderID CLocID
# 0                NaN     NaN    NaN
# 1                NaN     NaN    NaN
# 2                NaN     NaN    NaN
# 3                NaN     NaN    NaN
# 4                NaN     NaN    NaN
# ..               ...     ...    ...
# 495              NaN     NaN    NaN
# 496              NaN     NaN    NaN
# 497              NaN     NaN    NaN
# 498              NaN     NaN    NaN
# 499              NaN     NaN    NaN
#
# [500 rows x 11 columns]

# %%
df['IsOrderCompleted'] = df['DeliveryStatus'].apply(lambda x: 1 if x == 'Delivered' else 0)

# %%
df
# Out:
#      DeliveryID DeliveredDate  DeliveryDuration DeliveryStatus  \
# 0             1      2-1-2015                10      Delivered
# 1             2      6-4-2014                 3        Shipped
# 2             3     5-11-2018                10        Shipped
# 3             4      4-4-2020                 3      Delivered
# 4             5    15-10-2015                 3        Shipped
# ..          ...           ...               ...            ...
# 495         496     21-1-2015                10        Shipped
# 496         497     20-5-2015                10      Delivered
# 497         498      9-2-2014                10      Delivered
# 498         499     13-2-2019                 5      Delivered
# 499         500      7-6-2024                10      Delivered
#
#      QuantityDelivered PaymentDate PaymentMethod PaymentStatus  \
# 0                   11  05-01-2015          Card       Pending
# 1                    1  15-04-2014        Paypal       Pending
# 2                   10  06-11-2018          Card       Pending
# 3                    5  11-04-2020          Cash       Pending
# 4                    8  15-10-2015        Paypal       Pending
# ..                 ...         ...           ...           ...
# 495                  6  31-01-2015        Paypal          Paid
# 496                  7  10-05-2015          Card       Pending
# 497                  3  04-02-2014          Cash          Paid
# 498                  1  22-02-2019          Card       Pending
# 499                  1  31-05-2024        Paypal          Paid
#
#      IsOrderCompleted OrderID CLocID
# 0                   1     NaN    NaN
# 1                   0     NaN    NaN
# 2                   0     NaN    NaN
# 3                   1     NaN    NaN
# 4                   0     NaN    NaN
# ..                ...     ...    ...
# 495                 0     NaN    NaN
# 496                 1     NaN    NaN
# 497                 1     NaN    NaN
# 498                 1     NaN    NaN
# 499                 1     NaN    NaN
#
# [500 rows x 11 columns]

# %%
ids= []
for i in range(0,500):
   a=random.randint(1,200)
   ids.append(a)
df['OrderID'] = ids
df
# Out:
#      DeliveryID DeliveredDate  DeliveryDuration DeliveryStatus  \
# 0             1      2-1-2015                10      Delivered
# 1             2      6-4-2014                 3        Shipped
# 2             3     5-11-2018                10        Shipped
# 3             4      4-4-2020                 3      Delivered
# 4             5    15-10-2015                 3        Shipped
# ..          ...           ...               ...            ...
# 495         496     21-1-2015                10        Shipped
# 496         497     20-5-2015                10      Delivered
# 497         498      9-2-2014                10      Delivered
# 498         499     13-2-2019                 5      Delivered
# 499         500      7-6-2024                10      Delivered
#
#      QuantityDelivered PaymentDate PaymentMethod PaymentStatus  \
# 0                   11  05-01-2015          Card       Pending
# 1                    1  15-04-2014        Paypal       Pending
# 2                   10  06-11-2018          Card       Pending
# 3                    5  11-04-2020          Cash       Pending
# 4                    8  15-10-2015        Paypal       Pending
# ..                 ...         ...           ...           ...
# 495                  6  31-01-2015        Paypal          Paid
# 496                  7  10-05-2015          Card       Pending
# 497                  3  04-02-2014          Cash          Paid
# 498                  1  22-02-2019          Card       Pending
# 499                  1  31-05-2024        Paypal          Paid
#
#      IsOrderCompleted  OrderID CLocID
# 0                   1       73    NaN
# 1                   0       62    NaN
# 2                   0       26    NaN
# 3                   1      136    NaN
# 4                   0      131    NaN
# ..                ...      ...    ...
# 495                 0      118    NaN
# 496                 1       48    NaN
# 497                 1       72    NaN
# 498                 1       59    NaN
# 499                 1      138    NaN
#
# [500 rows x 11 columns]

# %%
ids= []
for i in range(0,500):
    a= random.randint(1,25)
    ids.append(a)

df['CLocID'] = ids
df
# Out:
#      DeliveryID DeliveredDate  DeliveryDuration DeliveryStatus  \
# 0             1      2-1-2015                10      Delivered
# 1             2      6-4-2014                 3        Shipped
# 2             3     5-11-2018                10        Shipped
# 3             4      4-4-2020                 3      Delivered
# 4             5    15-10-2015                 3        Shipped
# ..          ...           ...               ...            ...
# 495         496     21-1-2015                10        Shipped
# 496         497     20-5-2015                10      Delivered
# 497         498      9-2-2014                10      Delivered
# 498         499     13-2-2019                 5      Delivered
# 499         500      7-6-2024                10      Delivered
#
#      QuantityDelivered PaymentDate PaymentMethod PaymentStatus  \
# 0                   11  05-01-2015          Card       Pending
# 1                    1  15-04-2014        Paypal       Pending
# 2                   10  06-11-2018          Card       Pending
# 3                    5  11-04-2020          Cash       Pending
# 4                    8  15-10-2015        Paypal       Pending
# ..                 ...         ...           ...           ...
# 495                  6  31-01-2015        Paypal          Paid
# 496                  7  10-05-2015          Card       Pending
# 497                  3  04-02-2014          Cash          Paid
# 498                  1  22-02-2019          Card       Pending
# 499                  1  31-05-2024        Paypal          Paid
#
#      IsOrderCompleted  OrderID  CLocID
# 0                   1       73       9
# 1                   0       62      21
# 2                   0       26       7
# 3                   1      136      15
# 4                   0      131      24
# ..                ...      ...     ...
# 495                 0      118       4
# 496                 1       48       3
# 497                 1       72       8
# 498                 1       59       3
# 499                 1      138       9
#
# [500 rows x 11 columns]

# %%
df
# Out:
#      DeliveryID DeliveredDate  DeliveryDuration DeliveryStatus  \
# 0             1      2-1-2015                10      Delivered
# 1             2      6-4-2014                 3        Shipped
# 2             3     5-11-2018                10        Shipped
# 3             4      4-4-2020                 3      Delivered
# 4             5    15-10-2015                 3        Shipped
# ..          ...           ...               ...            ...
# 495         496     21-1-2015                10        Shipped
# 496         497     20-5-2015                10      Delivered
# 497         498      9-2-2014                10      Delivered
# 498         499     13-2-2019                 5      Delivered
# 499         500      7-6-2024                10      Delivered
#
#      QuantityDelivered PaymentDate PaymentMethod PaymentStatus  \
# 0                   11  05-01-2015          Card       Pending
# 1                    1  15-04-2014        Paypal       Pending
# 2                   10  06-11-2018          Card       Pending
# 3                    5  11-04-2020          Cash       Pending
# 4                    8  15-10-2015        Paypal       Pending
# ..                 ...         ...           ...           ...
# 495                  6  31-01-2015        Paypal          Paid
# 496                  7  10-05-2015          Card       Pending
# 497                  3  04-02-2014          Cash          Paid
# 498                  1  22-02-2019          Card       Pending
# 499                  1  31-05-2024        Paypal          Paid
#
#      IsOrderCompleted  OrderID  CLocID
# 0                   1       73       9
# 1                   0       62      21
# 2                   0       26       7
# 3                   1      136      15
# 4                   0      131      24
# ..                ...      ...     ...
# 495                 0      118       4
# 496                 1       48       3
# 497                 1       72       8
# 498                 1       59       3
# 499                 1      138       9
#
# [500 rows x 11 columns]

# %%
df.to_csv('Data/CustomerDeliveryOrder.csv',index=False)
