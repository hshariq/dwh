# %%
import pandas as pd
from faker import Faker

fake = Faker(use_weighting=True,locale='en_US')
# Out:
# C:\Users\hamza\AppData\Local\Temp\ipykernel_14904\564241095.py:1: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd

# %%
Warehouse = ['WarehouseID','ManagerID','WarehouseName','WarehousePhoneNumber','WarehouseCapacity', 'WarehouseCountry',
	'WarehouseState',
	'WarehouseCity',
	'WarehouseArea', 'WarehouseZIPCode', 'WarehouseTemparature',
 'IsTemperatureControlled', 'WarehouseCreationDate', 'WarehouseLife',
 'WarehouseUpdatedDate', 'IsWarehouseActive', 'WarehouseAccessHours',
 'WarehouseEmergencyExits', 'WarehouseCCTVs', 'WarehouseFireSuppressionSystem',
 'WarehouseRacks']


df = pd.DataFrame(columns=Warehouse)
df
# Out:
# Empty DataFrame
# Columns: [WarehouseID, ManagerID, WarehouseName, WarehousePhoneNumber, WarehouseCapacity, WarehouseCountry, WarehouseState, WarehouseCity, WarehouseArea, WarehouseZIPCode, WarehouseTemparature, IsTemperatureControlled, WarehouseCreationDate, WarehouseLife, WarehouseUpdatedDate, IsWarehouseActive, WarehouseAccessHours, WarehouseEmergencyExits, WarehouseCCTVs, WarehouseFireSuppressionSystem, WarehouseRacks]
# Index: []
#
# [0 rows x 21 columns]

# %%
ids= []
for i in range(0,15):
   ids.append(i+1)

df['WarehouseID'] = ids
df
# Out:
#     WarehouseID ManagerID WarehouseName WarehousePhoneNumber  \
# 0             1       NaN           NaN                  NaN
# 1             2       NaN           NaN                  NaN
# 2             3       NaN           NaN                  NaN
# 3             4       NaN           NaN                  NaN
# 4             5       NaN           NaN                  NaN
# 5             6       NaN           NaN                  NaN
# 6             7       NaN           NaN                  NaN
# 7             8       NaN           NaN                  NaN
# 8             9       NaN           NaN                  NaN
# 9            10       NaN           NaN                  NaN
# 10           11       NaN           NaN                  NaN
# 11           12       NaN           NaN                  NaN
# 12           13       NaN           NaN                  NaN
# 13           14       NaN           NaN                  NaN
# ...

# %%
for i in range(15):
    df.loc[i, 'WarehouseName'] = 'Warehouse' + str(i+1)
    
df
# Out:
#     WarehouseID ManagerID WarehouseName WarehousePhoneNumber  \
# 0             1       NaN    Warehouse1                  NaN
# 1             2       NaN    Warehouse2                  NaN
# 2             3       NaN    Warehouse3                  NaN
# 3             4       NaN    Warehouse4                  NaN
# 4             5       NaN    Warehouse5                  NaN
# 5             6       NaN    Warehouse6                  NaN
# 6             7       NaN    Warehouse7                  NaN
# 7             8       NaN    Warehouse8                  NaN
# 8             9       NaN    Warehouse9                  NaN
# 9            10       NaN   Warehouse10                  NaN
# 10           11       NaN   Warehouse11                  NaN
# 11           12       NaN   Warehouse12                  NaN
# 12           13       NaN   Warehouse13                  NaN
# 13           14       NaN   Warehouse14                  NaN
# ...

# %%
ids= []
for i in range(0,15):
   ids.append(i+1)

df['ManagerID'] = ids
df
# Out:
#     WarehouseID  ManagerID WarehouseName WarehousePhoneNumber  \
# 0             1          1    Warehouse1                  NaN
# 1             2          2    Warehouse2                  NaN
# 2             3          3    Warehouse3                  NaN
# 3             4          4    Warehouse4                  NaN
# 4             5          5    Warehouse5                  NaN
# 5             6          6    Warehouse6                  NaN
# 6             7          7    Warehouse7                  NaN
# 7             8          8    Warehouse8                  NaN
# 8             9          9    Warehouse9                  NaN
# 9            10         10   Warehouse10                  NaN
# 10           11         11   Warehouse11                  NaN
# 11           12         12   Warehouse12                  NaN
# 12           13         13   Warehouse13                  NaN
# 13           14         14   Warehouse14                  NaN
# ...

# %%
import random
phone_number = []

for i in range(0,15):
    area_code = random.randint(100, 999)
    prefix = random.randint(100, 999)
    line_number = random.randint(1000, 9999)
    phone_number.append(f"{area_code}-{prefix}-{line_number}")

df['WarehousePhoneNumber'] = phone_number
df
# Out:
#     WarehouseID  ManagerID WarehouseName WarehousePhoneNumber  \
# 0             1          1    Warehouse1         801-590-5098
# 1             2          2    Warehouse2         229-851-9619
# 2             3          3    Warehouse3         484-123-1754
# 3             4          4    Warehouse4         615-220-1013
# 4             5          5    Warehouse5         833-771-7140
# 5             6          6    Warehouse6         697-416-9994
# 6             7          7    Warehouse7         286-432-1907
# 7             8          8    Warehouse8         363-409-9751
# 8             9          9    Warehouse9         827-994-9152
# 9            10         10   Warehouse10         514-463-1556
# 10           11         11   Warehouse11         407-244-3999
# 11           12         12   Warehouse12         235-534-7216
# 12           13         13   Warehouse13         521-760-2984
# 13           14         14   Warehouse14         905-148-5085
# ...

# %%
import random
cap = []

for i in range(0,15):
    c = random.randint(100, 9999)
    cap.append(c)

df['WarehouseCapacity'] = cap
df
# Out:
#     WarehouseID  ManagerID WarehouseName WarehousePhoneNumber  \
# 0             1          1    Warehouse1         801-590-5098
# 1             2          2    Warehouse2         229-851-9619
# 2             3          3    Warehouse3         484-123-1754
# 3             4          4    Warehouse4         615-220-1013
# 4             5          5    Warehouse5         833-771-7140
# 5             6          6    Warehouse6         697-416-9994
# 6             7          7    Warehouse7         286-432-1907
# 7             8          8    Warehouse8         363-409-9751
# 8             9          9    Warehouse9         827-994-9152
# 9            10         10   Warehouse10         514-463-1556
# 10           11         11   Warehouse11         407-244-3999
# 11           12         12   Warehouse12         235-534-7216
# 12           13         13   Warehouse13         521-760-2984
# 13           14         14   Warehouse14         905-148-5085
# ...

# %%
import random
count = []

for i in range(0,15):
    c = random.randint(100, 9999)
    if c<1000:
        count.append('USA')
    elif c<2000:
        count.append('Pakistan')
    else:
        count.append('Canada')

df['WarehouseCountry'] = count
df
# Out:
#     WarehouseID  ManagerID WarehouseName WarehousePhoneNumber  \
# 0             1          1    Warehouse1         801-590-5098
# 1             2          2    Warehouse2         229-851-9619
# 2             3          3    Warehouse3         484-123-1754
# 3             4          4    Warehouse4         615-220-1013
# 4             5          5    Warehouse5         833-771-7140
# 5             6          6    Warehouse6         697-416-9994
# 6             7          7    Warehouse7         286-432-1907
# 7             8          8    Warehouse8         363-409-9751
# 8             9          9    Warehouse9         827-994-9152
# 9            10         10   Warehouse10         514-463-1556
# 10           11         11   Warehouse11         407-244-3999
# 11           12         12   Warehouse12         235-534-7216
# 12           13         13   Warehouse13         521-760-2984
# 13           14         14   Warehouse14         905-148-5085
# ...

# %%
import random
state = []

for i in range(0,15):
    c = random.randint(100, 9999)
    if df['WarehouseCountry'][i] == 'USA':   
        if c<1000:
            state.append('New York')
        elif c<2000:
            state.append('California')
        else:
            state.append('Texas')
    elif df['WarehouseCountry'][i] == 'Pakistan':
        if c<1000:
            state.append('Punjab')
        elif c<2000:
            state.append('Sindh')
        else:
            state.append('KPK')
    else:
        if c<1000:
            state.append('Ontario')
        elif c<2000:
            state.append('Quebec')
        else:
            state.append('British Columbia')
    
df['WarehouseState'] = state
df
# Out:
#     WarehouseID  ManagerID WarehouseName WarehousePhoneNumber  \
# 0             1          1    Warehouse1         801-590-5098
# 1             2          2    Warehouse2         229-851-9619
# 2             3          3    Warehouse3         484-123-1754
# 3             4          4    Warehouse4         615-220-1013
# 4             5          5    Warehouse5         833-771-7140
# 5             6          6    Warehouse6         697-416-9994
# 6             7          7    Warehouse7         286-432-1907
# 7             8          8    Warehouse8         363-409-9751
# 8             9          9    Warehouse9         827-994-9152
# 9            10         10   Warehouse10         514-463-1556
# 10           11         11   Warehouse11         407-244-3999
# 11           12         12   Warehouse12         235-534-7216
# 12           13         13   Warehouse13         521-760-2984
# 13           14         14   Warehouse14         905-148-5085
# ...

# %%
df
# Out:
#     WarehouseID  ManagerID WarehouseName WarehousePhoneNumber  \
# 0             1          1    Warehouse1         801-590-5098
# 1             2          2    Warehouse2         229-851-9619
# 2             3          3    Warehouse3         484-123-1754
# 3             4          4    Warehouse4         615-220-1013
# 4             5          5    Warehouse5         833-771-7140
# 5             6          6    Warehouse6         697-416-9994
# 6             7          7    Warehouse7         286-432-1907
# 7             8          8    Warehouse8         363-409-9751
# 8             9          9    Warehouse9         827-994-9152
# 9            10         10   Warehouse10         514-463-1556
# 10           11         11   Warehouse11         407-244-3999
# 11           12         12   Warehouse12         235-534-7216
# 12           13         13   Warehouse13         521-760-2984
# 13           14         14   Warehouse14         905-148-5085
# ...

# %%
import random
city = []

for i in range(0,15):
    c = random.randint(100, 9999)
    if df['WarehouseState'][i] == 'British Columbia':   
        if c<1000:
            city.append('Vancouver')
        elif c<2000:
            city.append('Victoria')
        else:
            city.append('Kelowna')
    elif df['WarehouseState'][i] == 'Ontario':
        if c<1000:
            city.append('Toronto')
        elif c<2000:
            city.append('Ottawa')
        else:
            city.append('Hamilton')
    elif df['WarehouseState'][i] == 'KPK':
            city.append('Peshawar')
    elif df['WarehouseState'][i] == 'Quebec':
        if c<1000:
            city.append('Montreal')
        elif c<2000:
            city.append('Quebec City')
        else:
            city.append('Sherbrooke')
    elif df['WarehouseState'][i] == 'Sindh':
        if c<1000:
            city.append('Karachi')
        elif c<2000:
            city.append('Hyderabad')
        else:
            city.append('Sukkur')
            
df['WarehouseCity'] = city
df
# Out:
#     WarehouseID  ManagerID WarehouseName WarehousePhoneNumber  \
# 0             1          1    Warehouse1         801-590-5098
# 1             2          2    Warehouse2         229-851-9619
# 2             3          3    Warehouse3         484-123-1754
# 3             4          4    Warehouse4         615-220-1013
# 4             5          5    Warehouse5         833-771-7140
# 5             6          6    Warehouse6         697-416-9994
# 6             7          7    Warehouse7         286-432-1907
# 7             8          8    Warehouse8         363-409-9751
# 8             9          9    Warehouse9         827-994-9152
# 9            10         10   Warehouse10         514-463-1556
# 10           11         11   Warehouse11         407-244-3999
# 11           12         12   Warehouse12         235-534-7216
# 12           13         13   Warehouse13         521-760-2984
# 13           14         14   Warehouse14         905-148-5085
# ...

# %%
for i in range(15):
    a=random.randint(100, 9999)
    df.loc[i, 'WarehouseArea'] = 'Area' + str(a)
    
df
# Out:
#     WarehouseID  ManagerID WarehouseName WarehousePhoneNumber  \
# 0             1          1    Warehouse1         801-590-5098
# 1             2          2    Warehouse2         229-851-9619
# 2             3          3    Warehouse3         484-123-1754
# 3             4          4    Warehouse4         615-220-1013
# 4             5          5    Warehouse5         833-771-7140
# 5             6          6    Warehouse6         697-416-9994
# 6             7          7    Warehouse7         286-432-1907
# 7             8          8    Warehouse8         363-409-9751
# 8             9          9    Warehouse9         827-994-9152
# 9            10         10   Warehouse10         514-463-1556
# 10           11         11   Warehouse11         407-244-3999
# 11           12         12   Warehouse12         235-534-7216
# 12           13         13   Warehouse13         521-760-2984
# 13           14         14   Warehouse14         905-148-5085
# ...

# %%
for i in range(15):
    a=random.randint(100, 9999)
    df.loc[i, 'WarehouseZIPCode'] = 'Zip' + str(a)
    
df
# Out:
#     WarehouseID  ManagerID WarehouseName WarehousePhoneNumber  \
# 0             1          1    Warehouse1         801-590-5098
# 1             2          2    Warehouse2         229-851-9619
# 2             3          3    Warehouse3         484-123-1754
# 3             4          4    Warehouse4         615-220-1013
# 4             5          5    Warehouse5         833-771-7140
# 5             6          6    Warehouse6         697-416-9994
# 6             7          7    Warehouse7         286-432-1907
# 7             8          8    Warehouse8         363-409-9751
# 8             9          9    Warehouse9         827-994-9152
# 9            10         10   Warehouse10         514-463-1556
# 10           11         11   Warehouse11         407-244-3999
# 11           12         12   Warehouse12         235-534-7216
# 12           13         13   Warehouse13         521-760-2984
# 13           14         14   Warehouse14         905-148-5085
# ...

# %%
for i in range(15):
    a=random.randint(0, 35)
    df.loc[i, 'WarehouseTemparature'] = a
    
df
# Out:
#     WarehouseID  ManagerID WarehouseName WarehousePhoneNumber  \
# 0             1          1    Warehouse1         801-590-5098
# 1             2          2    Warehouse2         229-851-9619
# 2             3          3    Warehouse3         484-123-1754
# 3             4          4    Warehouse4         615-220-1013
# 4             5          5    Warehouse5         833-771-7140
# 5             6          6    Warehouse6         697-416-9994
# 6             7          7    Warehouse7         286-432-1907
# 7             8          8    Warehouse8         363-409-9751
# 8             9          9    Warehouse9         827-994-9152
# 9            10         10   Warehouse10         514-463-1556
# 10           11         11   Warehouse11         407-244-3999
# 11           12         12   Warehouse12         235-534-7216
# 12           13         13   Warehouse13         521-760-2984
# 13           14         14   Warehouse14         905-148-5085
# ...

# %%
for i in range(15):
    a = random.randint(0, 1)
    df.loc[i, 'IsTemperatureControlled'] = a
    
# df['IsTemperatureControlled']

# %%
dates = []
for i in range(0,15):
    mm = random.randint(1,12)
    yy = random.randint(2005,2018)
    dd = random.randint(1,28)
    dates.append(f"{dd}-{mm}-{yy}")

df['WarehouseCreationDate'] = dates

df['WarehouseCreationDate']
# Out:
# 0      5-2-2008
# 1     16-7-2009
# 2     26-7-2017
# 3     20-4-2008
# 4      4-2-2010
# 5      5-9-2012
# 6     25-7-2017
# 7     16-6-2015
# 8      8-3-2016
# 9     23-9-2014
# 10     7-3-2007
# 11     9-5-2012
# 12    13-3-2011
# 13    16-7-2015
# 14     2-2-2009
# Name: WarehouseCreationDate, dtype: object

# %%
dur = []
for i in range(0,15):
    dur.append(2024 - int(df['WarehouseCreationDate'][i][-4:]))

df['WarehouseLife'] = dur
df['WarehouseLife']
# Out:
# 0     16
# 1     15
# 2      7
# 3     16
# 4     14
# 5     12
# 6      7
# 7      9
# 8      8
# 9     10
# 10    17
# 11    12
# 12    13
# 13     9
# 14    15
# Name: WarehouseLife, dtype: int64

# %%
dates = []
for i in range(0,15):
    mm = random.randint(1,12)
    yy = random.randint(2021,2023)
    dd = random.randint(1,28)
    dates.append(f"{dd}-{mm}-{yy}")

df['WarehouseUpdatedDate'] = dates

df['WarehouseUpdatedDate']
# Out:
# 0     26-2-2021
# 1      3-4-2022
# 2      6-5-2022
# 3     13-4-2022
# 4     19-3-2021
# 5     11-1-2022
# 6     15-7-2021
# 7      9-4-2022
# 8     2-11-2022
# 9     1-11-2021
# 10    16-6-2021
# 11     9-6-2023
# 12    12-6-2023
# 13     3-7-2021
# 14    22-7-2022
# Name: WarehouseUpdatedDate, dtype: object

# %%
for i in range(15):
    a = random.randint(0, 1)
    df.loc[i, 'IsWarehouseActive'] = a
    
df['IsWarehouseActive']
# Out:
# 0     1
# 1     1
# 2     0
# 3     1
# 4     0
# 5     0
# 6     1
# 7     1
# 8     0
# 9     0
# 10    1
# 11    1
# 12    0
# 13    0
# 14    0
# Name: IsWarehouseActive, dtype: object

# %%
for i in range(15):
    a = random.randint(0, 50)
    if a<10:
        df.loc[i, 'WarehouseAccessHours'] = '8:00 am - 5:00 pm'
    elif a<20:
        df.loc[i, 'WarehouseAccessHours'] = '9:00 am - 6:00 pm'
    elif a<30:
        df.loc[i, 'WarehouseAccessHours'] = '10:00 am - 7:00 pm'
    else:
        df.loc[i, 'WarehouseAccessHours'] = '11:00 am - 8:00 pm'
    
df['WarehouseAccessHours']
# Out:
# 0      9:00 am - 6:00 pm
# 1      9:00 am - 6:00 pm
# 2     10:00 am - 7:00 pm
# 3      8:00 am - 5:00 pm
# 4     11:00 am - 8:00 pm
# 5      9:00 am - 6:00 pm
# 6      8:00 am - 5:00 pm
# 7     11:00 am - 8:00 pm
# 8     10:00 am - 7:00 pm
# 9     10:00 am - 7:00 pm
# 10    10:00 am - 7:00 pm
# 11     8:00 am - 5:00 pm
# 12    11:00 am - 8:00 pm
# 13    11:00 am - 8:00 pm
# 14    11:00 am - 8:00 pm
# Name: WarehouseAccessHours, dtype: object

# %%
for i in range(15):
    a = random.randint(10, 50)
    df.loc[i, 'WarehouseEmergencyExits'] = a
    
df['WarehouseEmergencyExits']
# Out:
# 0     30
# 1     20
# 2     50
# 3     28
# 4     45
# 5     21
# 6     22
# 7     45
# 8     41
# 9     23
# 10    27
# 11    40
# 12    18
# 13    43
# 14    33
# Name: WarehouseEmergencyExits, dtype: object

# %%
for i in range(15):
    a = random.randint(50, 150)
    df.loc[i, 'WarehouseCCTVs'] = a
    
df['WarehouseCCTVs']
# Out:
# 0     131
# 1      89
# 2     123
# 3      92
# 4      59
# 5      70
# 6      94
# 7      82
# 8      64
# 9     101
# 10     82
# 11    131
# 12     56
# 13    127
# 14     94
# Name: WarehouseCCTVs, dtype: object

# %%
for i in range(15):
    a = random.randint(1, 20)
    df.loc[i, 'WarehouseFireSuppressionSystem'] = a
    
df['WarehouseFireSuppressionSystem']
# Out:
# 0     11
# 1      2
# 2     14
# 3     18
# 4      8
# 5     16
# 6      7
# 7      6
# 8      2
# 9     11
# 10     9
# 11     8
# 12    11
# 13     8
# 14    13
# Name: WarehouseFireSuppressionSystem, dtype: object

# %%
for i in range(15):
    a = random.randint(30, 500)
    df.loc[i, 'WarehouseRacks'] = a
    
df['WarehouseRacks']
# Out:
# 0     466
# 1     358
# 2     410
# 3     233
# 4     434
# 5     366
# 6     239
# 7      93
# 8     299
# 9     338
# 10    397
# 11    320
# 12    201
# 13    371
# 14     53
# Name: WarehouseRacks, dtype: object

# %%
df.to_csv("Warhouse.csv")
